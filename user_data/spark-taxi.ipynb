# %% [markdown]
# ## Configuração de Env e Sparks

# %%
import os
os.environ["JAVA_HOME"] = "/usr/local/openjdk-8"
os.environ["SPARK_HOME"] = "/user_data/spark-3.3.0-bin-hadoop2"

import findspark
findspark.init('spark-3.3.0-bin-hadoop2')

# %% [markdown]
# ## Imports

# %%
# Importando bibliotecas necessárias
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.stat import Correlation

spark = (
    SparkSession.builder.appName("spark_flight")
    .config("spark.sql.warehouse.dir", "hdfs:///user/hive/warehouse")
    .config("spark.sql.catalogImplementation", "hive")
    .getOrCreate()
)
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/user_data/spark-3.3.0-bin-hadoop2/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/hadoop-2.7.3/share/hadoop/common/lib/slf4j-log4j12-1.7.10.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/04 14:43:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Dataset escolhido
#
# O dataset escolhido foi o [Flight Status Prediction (link do Kaggle)](https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022/data). Esse dataset possui diversas informações sobre voos realizados, incluindo dados sobre cancelamento e atrasos.
#
# Apesar da disponibilidade de dados adquiridos desde 2018, selecionamos o arquivo CSV referente ao ano de 2022, que contém 1.42 GB de dados.

# %% [markdown]
# ## Leitura do dataset

# %%
dataframe = spark.read.csv("hdfs://spark-master:9000/datasets/taxi/yellow_tripdata_2016-03.csv", header=True, inferSchema=True)
num_linhas = dataframe.count()
print(f"Número de linhas no DataFrame: {num_linhas}")
# Out:
# [Stage 2:>                                                        (0 + 16) / 16]
# Número de linhas no DataFrame: 12210952

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)

# %%
# Visualizando o esquema dos dados
dataframe.printSchema()
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- pickup_longitude: double (nullable = true)
#  |-- pickup_latitude: double (nullable = true)
#  |-- RatecodeID: integer (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- dropoff_longitude: double (nullable = true)
#  |-- dropoff_latitude: double (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)

# %%
# 70% do dataset para rodar
dataframe_sample = dataframe.sample(fraction=0.7, seed=3)
print(f"Número de linhas no DataFrame Sample: {dataframe_sample.count()}")

# Exibindo algumas informações dos atributos
dataframe_sample.summary().show(truncate=False, vertical=True)
# Out:
# Número de linhas no DataFrame Sample: 8546588
# [Stage 78:>                                                         (0 + 1) / 1]
# -RECORD 0-------------------------------------
#  summary               | count
#  VendorID              | 8546588
#  passenger_count       | 8546588
#  trip_distance         | 8546588
#  pickup_longitude      | 8546588
#  pickup_latitude       | 8546588
#  RatecodeID            | 8546588
#  store_and_fwd_flag    | 8546588
#  dropoff_longitude     | 8546588
#  dropoff_latitude      | 8546588
#  payment_type          | 8546588
#  fare_amount           | 8546588
#  extra                 | 8546588
#  mta_tax               | 8546588
#  tip_amount            | 8546588
#  tolls_amount          | 8546588
#  improvement_surcharge | 8546588
#  total_amount          | 8546588
# -RECORD 1-------------------------------------
#  summary               | mean
#  VendorID              | 1.5305298441904536
#  passenger_count       | 1.6597577887222363
#  trip_distance         | 4.15993894054566
#  pickup_longitude      | -72.86853037352815
#  pickup_latitude       | 40.14195524703888
#  RatecodeID            | 1.0405120733560573
#  store_and_fwd_flag    | null
#  dropoff_longitude     | -72.93520866921507
#  dropoff_latitude      | 40.17964044389975
#  payment_type          | 1.3408963904659965
#  fare_amount           | 12.787266259939006
#  extra                 | 0.34545774407283936
#  mta_tax               | 0.4976463648417356
#  tip_amount            | 1.7922203492196562
#  tolls_amount          | 0.3148760721822408
#  improvement_surcharge | 0.2997194131735774
#  total_amount          | 16.03717500123564
# -RECORD 2-------------------------------------
#  summary               | stddev
#  VendorID              | 0.4990670874302303
#  passenger_count       | 1.3125362271470467
#  trip_distance         | 1855.0202025398376
#  pickup_longitude      | 8.975360095483133
#  pickup_latitude       | 4.944157278516049
#  RatecodeID            | 0.594681702138101
#  store_and_fwd_flag    | null
#  dropoff_longitude     | 8.703435357159092
#  dropoff_latitude      | 4.7944870187417115
#  payment_type          | 0.49032243426465716
#  fare_amount           | 147.3146519084742
#  extra                 | 0.4555832389987282
#  mta_tax               | 0.04858488224106413
#  tip_amount            | 2.523712059352001
#  tolls_amount          | 1.6610723646477894
#  improvement_surcharge | 0.012326936002027916
#  total_amount          | 147.55010279056577
# -RECORD 3-------------------------------------
#  summary               | min
#  VendorID              | 1
#  passenger_count       | 0
#  trip_distance         | 0.0
#  pickup_longitude      | -161.69866943359375
#  pickup_latitude       | 0.0
#  RatecodeID            | 1
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -121.93348693847656
#  dropoff_latitude      | 0.0
#  payment_type          | 1
#  fare_amount           | -376.0
#  extra                 | -41.7
#  mta_tax               | -1.0
#  tip_amount            | -16.7
#  tolls_amount          | -16.04
#  improvement_surcharge | -0.3
#  total_amount          | -376.3
# -RECORD 4-------------------------------------
#  summary               | 25%
#  VendorID              | 1
#  passenger_count       | 1
#  trip_distance         | 1.0
#  pickup_longitude      | -73.99174499511719
#  pickup_latitude       | 40.736305236816406
#  RatecodeID            | 1
#  store_and_fwd_flag    | null
#  dropoff_longitude     | -73.99124908447266
#  dropoff_latitude      | 40.73463439941406
#  payment_type          | 1
#  fare_amount           | 6.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 8.75
# -RECORD 5-------------------------------------
#  summary               | 50%
#  VendorID              | 2
#  passenger_count       | 1
#  trip_distance         | 1.7
#  pickup_longitude      | -73.98161315917969
#  pickup_latitude       | 40.75325012207031
#  RatecodeID            | 1
#  store_and_fwd_flag    | null
#  dropoff_longitude     | -73.97960662841797
#  dropoff_latitude      | 40.753753662109375
#  payment_type          | 1
#  fare_amount           | 9.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 1.35
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 11.8
# -RECORD 6-------------------------------------
#  summary               | 75%
#  VendorID              | 2
#  passenger_count       | 2
#  trip_distance         | 3.18
#  pickup_longitude      | -73.9667739868164
#  pickup_latitude       | 40.767642974853516
#  RatecodeID            | 1
#  store_and_fwd_flag    | null
#  dropoff_longitude     | -73.9622802734375
#  dropoff_latitude      | 40.769100189208984
#  payment_type          | 2
#  fare_amount           | 14.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.36
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 17.76
# -RECORD 7-------------------------------------
#  summary               | max
#  VendorID              | 2
#  passenger_count       | 9
#  trip_distance         | 5000000.0
#  pickup_longitude      | 0.0
#  pickup_latitude       | 66.85681915283203
#  RatecodeID            | 99
#  store_and_fwd_flag    | Y
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 50.7978630065918
#  payment_type          | 4
#  fare_amount           | 429496.72
#  extra                 | 80.0
#  mta_tax               | 79.3
#  tip_amount            | 440.25
#  tolls_amount          | 915.0
#  improvement_surcharge | 0.3
#  total_amount          | 429562.25

# %%
# Mostrando as primeiras linhas do DataFrame
dataframe.show(n=5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  VendorID              | 1
#  tpep_pickup_datetime  | 2016-03-01 00:00:00
#  tpep_dropoff_datetime | 2016-03-01 00:07:55
#  passenger_count       | 1
#  trip_distance         | 2.5
#  pickup_longitude      | -73.97674560546875
#  pickup_latitude       | 40.76515197753906
#  RatecodeID            | 1
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -74.00426483154297
#  dropoff_latitude      | 40.74612808227539
#  payment_type          | 1
#  fare_amount           | 9.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.05
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.35
# -RECORD 1------------------------------------
#  VendorID              | 1
#  tpep_pickup_datetime  | 2016-03-01 00:00:00
#  tpep_dropoff_datetime | 2016-03-01 00:11:06
#  passenger_count       | 1
#  trip_distance         | 2.9
#  pickup_longitude      | -73.98348236083984
#  pickup_latitude       | 40.76792526245117
#  RatecodeID            | 1
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -74.00594329833984
#  dropoff_latitude      | 40.7331657409668
#  payment_type          | 1
#  fare_amount           | 11.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 3.05
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 15.35
# -RECORD 2------------------------------------
#  VendorID              | 2
#  tpep_pickup_datetime  | 2016-03-01 00:00:00
#  tpep_dropoff_datetime | 2016-03-01 00:31:06
#  passenger_count       | 2
#  trip_distance         | 19.98
#  pickup_longitude      | -73.78202056884766
#  pickup_latitude       | 40.64480972290039
#  RatecodeID            | 1
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -73.97454071044922
#  dropoff_latitude      | 40.6757698059082
#  payment_type          | 1
#  fare_amount           | 54.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 8.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 63.8
# -RECORD 3------------------------------------
#  VendorID              | 2
#  tpep_pickup_datetime  | 2016-03-01 00:00:00
#  tpep_dropoff_datetime | 2016-03-01 00:00:00
#  passenger_count       | 3
#  trip_distance         | 10.78
#  pickup_longitude      | -73.86341857910156
#  pickup_latitude       | 40.769813537597656
#  RatecodeID            | 1
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -73.96965026855469
#  dropoff_latitude      | 40.75776672363281
#  payment_type          | 1
#  fare_amount           | 31.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 3.78
#  tolls_amount          | 5.54
#  improvement_surcharge | 0.3
#  total_amount          | 41.62
# -RECORD 4------------------------------------
#  VendorID              | 2
#  tpep_pickup_datetime  | 2016-03-01 00:00:00
#  tpep_dropoff_datetime | 2016-03-01 00:00:00
#  passenger_count       | 5
#  trip_distance         | 30.43
#  pickup_longitude      | -73.97174072265625
#  pickup_latitude       | 40.79218292236328
#  RatecodeID            | 3
#  store_and_fwd_flag    | N
#  dropoff_longitude     | -74.17716979980469
#  dropoff_latitude      | 40.69505310058594
#  payment_type          | 1
#  fare_amount           | 98.0
#  extra                 | 0.0
#  mta_tax               | 0.0
#  tip_amount            | 0.0
#  tolls_amount          | 15.5
#  improvement_surcharge | 0.3
#  total_amount          | 113.8
# only showing top 5 rows

# %%
# Checagem por dados nulos
Dict_Null = {col:dataframe_sample.filter(dataframe_sample[col].isNull()).count() for col in dataframe_sample.columns}
Dict_Null
# Out:
# {'VendorID': 0,
#  'tpep_pickup_datetime': 0,
#  'tpep_dropoff_datetime': 0,
#  'passenger_count': 0,
#  'trip_distance': 0,
#  'pickup_longitude': 0,
#  'pickup_latitude': 0,
#  'RatecodeID': 0,
#  'store_and_fwd_flag': 0,
#  'dropoff_longitude': 0,
#  'dropoff_latitude': 0,
#  'payment_type': 0,
#  'fare_amount': 0,
#  'extra': 0,
#  'mta_tax': 0,
#  'tip_amount': 0,
#  'tolls_amount': 0,
#  'improvement_surcharge': 0,
#  'total_amount': 0}

# %% [markdown]
# Pudemos visualizar que existem alguns dados nulos principalmente nas colunas referentes ao tempo de viagem, como o delay na partida ou chegada e tempo de voo.

# %% [markdown]
# ## Pré-processamento

# %%
# Remover colunas de ID e nome do DataFrame
colunas_para_remover = [
'VendorID',
 'tpep_pickup_datetime',
 'tpep_dropoff_datetime',
 'RatecodeID',
]

dataframe_sem_colunas_de_id = dataframe_sample.drop(*colunas_para_remover)

# Mostrar somente o nome das colunas
print("Nome das colunas:")
for coluna in dataframe_sem_colunas_de_id.columns:
    print(coluna)
# Out:
# Nome das colunas:
# passenger_count
# trip_distance
# pickup_longitude
# pickup_latitude
# store_and_fwd_flag
# dropoff_longitude
# dropoff_latitude
# payment_type
# fare_amount
# extra
# mta_tax
# tip_amount
# tolls_amount
# improvement_surcharge
# total_amount

# %%
from pyspark.sql.functions import when

dataframe_sem_valores_nulos = dataframe_sem_valores_nulos.withColumn("store_and_fwd_flag", when(col("store_and_fwd_flag") == 'Y', 1).otherwise(0))
dataframe_sem_valores_nulos.show(n=5, truncate=False, vertical=True)

# Correlação
assembler = VectorAssembler(inputCols=dataframe_sem_valores_nulos.columns, outputCol="features")
dataframe_vetorizado = assembler.transform(dataframe_sem_valores_nulos)

correlation = Correlation.corr(dataframe_vetorizado, "features", method="pearson").collect()[0][0]

rows = correlation.toArray().tolist()
spark.createDataFrame(rows,dataframe_sem_valores_nulos.columns).show(n=30, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  passenger_count       | 1
#  trip_distance         | 2.5
#  pickup_longitude      | -73.97674560546875
#  pickup_latitude       | 40.76515197753906
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -74.00426483154297
#  dropoff_latitude      | 40.74612808227539
#  payment_type          | 1
#  fare_amount           | 9.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.05
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.35
# -RECORD 1-----------------------------------
#  passenger_count       | 1
#  trip_distance         | 2.0
#  pickup_longitude      | -74.00672912597656
#  pickup_latitude       | 40.730716705322266
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -74.01704406738281
#  dropoff_latitude      | 40.70936584472656
#  payment_type          | 1
#  fare_amount           | 8.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 11.8
# -RECORD 2-----------------------------------
#  passenger_count       | 1
#  trip_distance         | 3.2
#  pickup_longitude      | -74.0066146850586
#  pickup_latitude       | 40.71662139892578
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -73.99010467529297
#  dropoff_latitude      | 40.75605010986328
#  payment_type          | 2
#  fare_amount           | 11.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.3
# -RECORD 3-----------------------------------
#  passenger_count       | 1
#  trip_distance         | 1.59
#  pickup_longitude      | -73.98226928710938
#  pickup_latitude       | 40.7706184387207
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -73.96874237060547
#  dropoff_latitude      | 40.75503921508789
#  payment_type          | 1
#  fare_amount           | 8.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 1.86
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 11.16
# -RECORD 4-----------------------------------
#  passenger_count       | 1
#  trip_distance         | 3.5
#  pickup_longitude      | -74.00041961669922
#  pickup_latitude       | 40.72746276855469
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -73.94773864746094
#  dropoff_latitude      | 40.70987319946289
#  payment_type          | 2
#  fare_amount           | 13.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 14.3
# only showing top 5 rows
# 24/05/04 15:02:23 WARN PearsonCorrelation: Pearson correlation matrix contains NaN values.
# -RECORD 0---------------------------------------
#  passenger_count       | 1.0
#  trip_distance         | -5.263318328016018E-4
#  pickup_longitude      | -0.01756957887859424
#  pickup_latitude       | 0.017537438727294703
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.015379834179621667
#  dropoff_latitude      | 0.015350113919973317
#  payment_type          | 0.02175554777893588
#  fare_amount           | 0.008612146645432929
#  extra                 | 0.0012962471610263589
#  mta_tax               | 0.005080171589824292
#  tip_amount            | -0.024930887828952437
#  tolls_amount          | -2.9409326707183393E-4
#  improvement_surcharge | 0.0030607063591546833
#  total_amount          | -0.0011767825074115372
# -RECORD 1---------------------------------------
#  passenger_count       | -5.263318328016018E-4
#  trip_distance         | 1.0
#  pickup_longitude      | -1.4559867850246654E-4
#  pickup_latitude       | 1.438668050792304E-4
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -1.662161268934875E-4
#  dropoff_latitude      | 1.687184819176983E-4
#  payment_type          | 6.403135679335928E-4
#  fare_amount           | 0.0032607166260662
#  extra                 | 3.1347658950517783E-4
#  mta_tax               | 3.721576595770734E-4
#  tip_amount            | -0.0013545269950345153
#  tolls_amount          | 6.604143438699366E-5
#  improvement_surcharge | -4.873407805163729E-6
#  total_amount          | 0.002686216492846842
# -RECORD 2---------------------------------------
#  passenger_count       | -0.01756957887859424
#  trip_distance         | -1.4559867850246654E-4
#  pickup_longitude      | 1.0
#  pickup_latitude       | -0.9999614187975425
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 0.8909324370074516
#  dropoff_latitude      | -0.8909203394641986
#  payment_type          | -3.2146840615356493E-4
#  fare_amount           | 8.743883122396439E-5
#  extra                 | 1.5035449685724334E-4
#  mta_tax               | -0.02335110815449589
#  tip_amount            | -3.15862990176688E-4
#  tolls_amount          | -9.908718844810402E-4
#  improvement_surcharge | -0.01221719615532439
#  total_amount          | -3.122285872132444E-4
# -RECORD 3---------------------------------------
#  passenger_count       | 0.017537438727294703
#  trip_distance         | 1.438668050792304E-4
#  pickup_longitude      | -0.9999614187975425
#  pickup_latitude       | 1.0
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.8909033553786124
#  dropoff_latitude      | 0.8909584837700135
#  payment_type          | 6.525976621220889E-4
#  fare_amount           | -1.3966154927986033E-4
#  extra                 | -4.723975868200264E-4
#  mta_tax               | 0.023391015517767334
#  tip_amount            | -2.798208038280527E-5
#  tolls_amount          | 9.495922448499516E-4
#  improvement_surcharge | 0.012795404351263848
#  total_amount          | 6.936502890022508E-5
# -RECORD 4---------------------------------------
#  passenger_count       | NaN
#  trip_distance         | NaN
#  pickup_longitude      | NaN
#  pickup_latitude       | NaN
#  store_and_fwd_flag    | 1.0
#  dropoff_longitude     | NaN
#  dropoff_latitude      | NaN
#  payment_type          | NaN
#  fare_amount           | NaN
#  extra                 | NaN
#  mta_tax               | NaN
#  tip_amount            | NaN
#  tolls_amount          | NaN
#  improvement_surcharge | NaN
#  total_amount          | NaN
# -RECORD 5---------------------------------------
#  passenger_count       | -0.015379834179621667
#  trip_distance         | -1.662161268934875E-4
#  pickup_longitude      | 0.8909324370074516
#  pickup_latitude       | -0.8909033553786124
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 1.0
#  dropoff_latitude      | -0.9999216409709635
#  payment_type          | 0.00708344883842566
#  fare_amount           | 0.002271708442161306
#  extra                 | 0.0022451366390463935
#  mta_tax               | -0.01837832173506795
#  tip_amount            | -0.007208818637060608
#  tolls_amount          | 2.8547875321861826E-4
#  improvement_surcharge | -0.020716300364028006
#  total_amount          | -3.688479446813171E-4
# -RECORD 6---------------------------------------
#  passenger_count       | 0.015350113919973317
#  trip_distance         | 1.687184819176983E-4
#  pickup_longitude      | -0.8909203394641986
#  pickup_latitude       | 0.8909584837700135
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.9999216409709635
#  dropoff_latitude      | 1.0
#  payment_type          | -0.006701262534967345
#  fare_amount           | -0.002207913627784132
#  extra                 | -0.0023691665704673594
#  mta_tax               | 0.018419509540810827
#  tip_amount            | 0.006811476758131317
#  tolls_amount          | -3.057438237448543E-4
#  improvement_surcharge | 0.021318893261022296
#  total_amount          | 2.5308709492580364E-4
# -RECORD 7---------------------------------------
#  passenger_count       | 0.02175554777893588
#  trip_distance         | 6.403135679335928E-4
#  pickup_longitude      | -3.2146840615356493E-4
#  pickup_latitude       | 6.525976621220889E-4
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 0.00708344883842566
#  dropoff_latitude      | -0.006701262534967345
#  payment_type          | 1.0
#  fare_amount           | 0.1739880428672749
#  extra                 | 0.004631877476768176
#  mta_tax               | 0.0076211137806220085
#  tip_amount            | -0.8669168429733141
#  tolls_amount          | 0.01167657749912715
#  improvement_surcharge | -1.3434530095181066E-4
#  total_amount          | -0.1681295960317434
# -RECORD 8---------------------------------------
#  passenger_count       | 0.008612146645432929
#  trip_distance         | 0.0032607166260662
#  pickup_longitude      | 8.743883122396439E-5
#  pickup_latitude       | -1.3966154927986033E-4
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 0.002271708442161306
#  dropoff_latitude      | -0.002207913627784132
#  payment_type          | 0.1739880428672749
#  fare_amount           | 1.0
#  extra                 | -0.009864032138116728
#  mta_tax               | -0.002351667067984237
#  tip_amount            | -0.17083400822503067
#  tolls_amount          | 0.025260386990024718
#  improvement_surcharge | -0.0032519896906568367
#  total_amount          | 0.9009477779293347
# -RECORD 9---------------------------------------
#  passenger_count       | 0.0012962471610263589
#  trip_distance         | 3.1347658950517783E-4
#  pickup_longitude      | 1.5035449685724334E-4
#  pickup_latitude       | -4.723975868200264E-4
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 0.0022451366390463935
#  dropoff_latitude      | -0.0023691665704673594
#  payment_type          | 0.004631877476768176
#  fare_amount           | -0.009864032138116728
#  extra                 | 1.0
#  mta_tax               | 0.012135134729426228
#  tip_amount            | 0.0035040199618998806
#  tolls_amount          | 0.0030494131467303565
#  improvement_surcharge | 0.004544313537980566
#  total_amount          | 0.16172341150940447
# -RECORD 10--------------------------------------
#  passenger_count       | 0.005080171589824292
#  trip_distance         | 3.721576595770734E-4
#  pickup_longitude      | -0.02335110815449589
#  pickup_latitude       | 0.023391015517767334
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.01837832173506795
#  dropoff_latitude      | 0.018419509540810827
#  payment_type          | 0.0076211137806220085
#  fare_amount           | -0.002351667067984237
#  extra                 | 0.012135134729426228
#  mta_tax               | 1.0
#  tip_amount            | 4.829525771838249E-4
#  tolls_amount          | -9.080108942532931E-5
#  improvement_surcharge | -0.013905752034665849
#  total_amount          | 0.007726966021227383
# -RECORD 11--------------------------------------
#  passenger_count       | -0.024930887828952437
#  trip_distance         | -0.0013545269950345153
#  pickup_longitude      | -3.15862990176688E-4
#  pickup_latitude       | -2.798208038280527E-5
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.007208818637060608
#  dropoff_latitude      | 0.006811476758131317
#  payment_type          | -0.8669168429733141
#  fare_amount           | -0.17083400822503067
#  extra                 | 0.0035040199618998806
#  mta_tax               | 4.829525771838249E-4
#  tip_amount            | 1.0
#  tolls_amount          | -0.007763540308176524
#  improvement_surcharge | 0.0033126996508872617
#  total_amount          | 0.224992067461172
# -RECORD 12--------------------------------------
#  passenger_count       | -2.9409326707183393E-4
#  trip_distance         | 6.604143438699366E-5
#  pickup_longitude      | -9.908718844810402E-4
#  pickup_latitude       | 9.495922448499516E-4
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | 2.8547875321861826E-4
#  dropoff_latitude      | -3.057438237448543E-4
#  payment_type          | 0.01167657749912715
#  fare_amount           | 0.025260386990024718
#  extra                 | 0.0030494131467303565
#  mta_tax               | -9.080108942532931E-5
#  tip_amount            | -0.007763540308176524
#  tolls_amount          | 1.0
#  improvement_surcharge | -8.826865483094624E-4
#  total_amount          | 0.1290755571571821
# -RECORD 13--------------------------------------
#  passenger_count       | 0.0030607063591546833
#  trip_distance         | -4.873407805163729E-6
#  pickup_longitude      | -0.01221719615532439
#  pickup_latitude       | 0.012795404351263848
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -0.020716300364028006
#  dropoff_latitude      | 0.021318893261022296
#  payment_type          | -1.3434530095181066E-4
#  fare_amount           | -0.0032519896906568367
#  extra                 | 0.004544313537980566
#  mta_tax               | -0.013905752034665849
#  tip_amount            | 0.0033126996508872617
#  tolls_amount          | -8.826865483094624E-4
#  improvement_surcharge | 1.0
#  total_amount          | -3.727036492229694E-4
# -RECORD 14--------------------------------------
#  passenger_count       | -0.0011767825074115372
#  trip_distance         | 0.002686216492846842
#  pickup_longitude      | -3.122285872132444E-4
#  pickup_latitude       | 6.936502890022508E-5
#  store_and_fwd_flag    | NaN
#  dropoff_longitude     | -3.688479446813171E-4
#  dropoff_latitude      | 2.5308709492580364E-4
#  payment_type          | -0.1681295960317434
#  fare_amount           | 0.9009477779293347
#  extra                 | 0.16172341150940447
#  mta_tax               | 0.007726966021227383
#  tip_amount            | 0.224992067461172
#  tolls_amount          | 0.1290755571571821
#  improvement_surcharge | -3.727036492229694E-4
#  total_amount          | 1.0

# %%
# Criando um vetor de features para o modelo
target = 'tip_amount'
feature_columns = dataframe_sem_valores_nulos.columns
feature_columns.remove(target)

vector_assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
dataframe_vetorizado_sem_target = vector_assembler.transform(dataframe_sem_valores_nulos)

# %%
# Dividindo o conjunto de dados em treino e teste
train_data, test_data = dataframe_vetorizado_sem_target.randomSplit([0.8, 0.2], seed=3)

# %% [markdown]
# ## Regressão linear

# %%
from pyspark.ml.regression import LinearRegression

regressor = LinearRegression(featuresCol = 'features', labelCol = 'tip_amount', loss='squaredError', maxIter=50, regParam = 0.05)
regressor = regressor.fit(train_data)

# %%
pred_results = regressor.evaluate(test_data)
pred_results.predictions.show(n=5, truncate=False, vertical=True)

# Printing the results
print('MAE:', pred_results.meanAbsoluteError)
print('MSE:', pred_results.meanSquaredError)
print('RMSE:', pred_results.rootMeanSquaredError)
print('R2-Score:', pred_results.r2)
# Out:
# 24/05/04 15:23:12 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# [Stage 177:>                                                        (0 + 1) / 1]
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.01785278320312
#  pickup_latitude       | 40.706382751464844
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -74.00518798828125
#  dropoff_latitude      | 40.73393630981445
#  payment_type          | 2
#  fare_amount           | 9.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 10.3
#  features              | [1.0,0.0,-74.01785278320312,40.706382751464844,0.0,-74.00518798828125,40.73393630981445,2.0,9.5,0.0,0.5,0.0,0.3,10.3]
#  prediction            | 0.05549311416913816
# -RECORD 1--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.01044464111328
#  pickup_latitude       | 40.718894958496094
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 11.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.3
#  features              | [1.0,0.0,-74.01044464111328,40.718894958496094,0.0,0.0,0.0,2.0,11.0,0.5,0.5,0.0,0.3,12.3]
#  prediction            | 0.0613765895308267
# -RECORD 2--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.00758361816406
#  pickup_latitude       | 40.74091720581055
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 8.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 8.8
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.00758361816406,40.74091720581055,2.0,8.0,0.5,0.3,8.8])
#  prediction            | 0.023857920353703266
# -RECORD 3--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.0073471069336
#  pickup_latitude       | 40.72811508178711
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 11.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.3
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.0073471069336,40.72811508178711,2.0,11.5,0.5,0.3,12.3])
#  prediction            | 0.05155488345734027
# -RECORD 4--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.0064926147461
#  pickup_latitude       | 40.732303619384766
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 7.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.0064926147461,40.732303619384766,2.0,7.0,0.5,0.3,7.8])
#  prediction            | 0.015947546113544542
# only showing top 5 rows
#
# MAE: 0.2145924166445675
# MSE: 0.09649804072185605
# RMSE: 0.31064133775442065
# R2-Score: 0.8700940991836612

# %% [markdown]
# ### Árvore de decisão

# %%
from pyspark.ml.regression import DecisionTreeRegressor
dt = DecisionTreeRegressor(featuresCol = 'features', labelCol = 'tip_amount', maxDepth=5)
model = dt.fit(train_data)

# %%
pred_results = model.transform(test_data)
pred_results.show(n=5, truncate=False, vertical=True)

# Printing the results
evaluator = RegressionEvaluator(predictionCol = 'prediction', labelCol = 'tip_amount')

mae = evaluator.evaluate(pred_results,
{evaluator.metricName: "mae"})

mse = evaluator.evaluate(pred_results,
{evaluator.metricName: "mse"})

rmse = evaluator.evaluate(pred_results,
{evaluator.metricName: "rmse"})

r2 = evaluator.evaluate(pred_results,
{evaluator.metricName: "r2"})

print('MAE:', mae)
print('MSE:', mse)
print('RMSE:', rmse)
print('R2-Score:', r2)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.01785278320312
#  pickup_latitude       | 40.706382751464844
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | -74.00518798828125
#  dropoff_latitude      | 40.73393630981445
#  payment_type          | 2
#  fare_amount           | 9.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 10.3
#  features              | [1.0,0.0,-74.01785278320312,40.706382751464844,0.0,-74.00518798828125,40.73393630981445,2.0,9.5,0.0,0.5,0.0,0.3,10.3]
#  prediction            | 1.3750554457841043E-5
# -RECORD 1--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.01044464111328
#  pickup_latitude       | 40.718894958496094
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 11.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.3
#  features              | [1.0,0.0,-74.01044464111328,40.718894958496094,0.0,0.0,0.0,2.0,11.0,0.5,0.5,0.0,0.3,12.3]
#  prediction            | 0.0
# -RECORD 2--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.00758361816406
#  pickup_latitude       | 40.74091720581055
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 8.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 8.8
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.00758361816406,40.74091720581055,2.0,8.0,0.5,0.3,8.8])
#  prediction            | 1.3750554457841043E-5
# -RECORD 3--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.0073471069336
#  pickup_latitude       | 40.72811508178711
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 11.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 12.3
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.0073471069336,40.72811508178711,2.0,11.5,0.5,0.3,12.3])
#  prediction            | 0.0
# -RECORD 4--------------------------------------------------------------------------------------------------------------------------------------
#  passenger_count       | 1
#  trip_distance         | 0.0
#  pickup_longitude      | -74.0064926147461
#  pickup_latitude       | 40.732303619384766
#  store_and_fwd_flag    | 0
#  dropoff_longitude     | 0.0
#  dropoff_latitude      | 0.0
#  payment_type          | 2
#  fare_amount           | 7.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  features              | (14,[0,2,3,7,8,10,12,13],[1.0,-74.0064926147461,40.732303619384766,2.0,7.0,0.5,0.3,7.8])
#  prediction            | 1.3750554457841043E-5
# only showing top 5 rows
# Exception ignored in: <function JavaWrapper.__del__ at 0x7f14859bd1f0>
# Traceback (most recent call last):
#   File "spark-3.3.0-bin-hadoop2/python/pyspark/ml/wrapper.py", line 53, in __del__
#     if SparkContext._active_spark_context and self._java_obj is not None:
# AttributeError: 'RegressionEvaluator' object has no attribute '_java_obj'
# [Stage 225:>                                                      (0 + 16) / 16]
# MAE: 0.1567148249167305
# MSE: 0.08861165792549609
# RMSE: 0.29767710346194937
# R2-Score: 0.8807107671872798

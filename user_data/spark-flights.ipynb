# %% [markdown]
# ## Configuração de Env e Sparks

# %%
import os
os.environ["JAVA_HOME"] = "/usr/local/openjdk-8"
os.environ["SPARK_HOME"] = "/user_data/spark-3.3.0-bin-hadoop2"

import findspark
findspark.init('spark-3.3.0-bin-hadoop2')

# %% [markdown]
# ## Imports

# %%
# Importando bibliotecas necessárias
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.stat import Correlation

spark = (
    SparkSession.builder.appName("spark_flight")
    .config("spark.sql.warehouse.dir", "hdfs:///user/hive/warehouse")
    .config("spark.sql.catalogImplementation", "hive")
    .getOrCreate()
)
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/user_data/spark-3.3.0-bin-hadoop2/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/hadoop-2.7.3/share/hadoop/common/lib/slf4j-log4j12-1.7.10.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/30 02:33:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Dataset escolhido
#
# O dataset escolhido foi o [Flight Status Prediction (link do Kaggle)](https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022/data). Esse dataset possui diversas informações sobre voos realizados, incluindo dados sobre cancelamento e atrasos.
#
# Apesar da disponibilidade de dados adquiridos desde 2018, selecionamos o arquivo CSV referente ao ano de 2022, que contém 1.42 GB de dados.

# %% [markdown]
# ## Leitura do dataset

# %%
dataframe = spark.read.csv("hdfs://spark-master:9000/datasets/flights/Combined_Flights_2022.csv", header=True, inferSchema=True)
num_linhas = dataframe.count()
print(f"Número de linhas no DataFrame: {num_linhas}")
# Out:
# [Stage 2:>                                                        (0 + 16) / 16]
# Número de linhas no DataFrame: 4078318

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)

# %%
# Visualizando o esquema dos dados
dataframe.printSchema()
# Out:
# root
#  |-- FlightDate: timestamp (nullable = true)
#  |-- Airline: string (nullable = true)
#  |-- Origin: string (nullable = true)
#  |-- Dest: string (nullable = true)
#  |-- Cancelled: boolean (nullable = true)
#  |-- Diverted: boolean (nullable = true)
#  |-- CRSDepTime: integer (nullable = true)
#  |-- DepTime: double (nullable = true)
#  |-- DepDelayMinutes: double (nullable = true)
#  |-- DepDelay: double (nullable = true)
#  |-- ArrTime: double (nullable = true)
#  |-- ArrDelayMinutes: double (nullable = true)
#  |-- AirTime: double (nullable = true)
#  |-- CRSElapsedTime: double (nullable = true)
#  |-- ActualElapsedTime: double (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Quarter: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- DayofMonth: integer (nullable = true)
#  |-- DayOfWeek: integer (nullable = true)
#  |-- Marketing_Airline_Network: string (nullable = true)
#  |-- Operated_or_Branded_Code_Share_Partners: string (nullable = true)
#  |-- DOT_ID_Marketing_Airline: integer (nullable = true)
#  |-- IATA_Code_Marketing_Airline: string (nullable = true)
#  |-- Flight_Number_Marketing_Airline: integer (nullable = true)
#  |-- Operating_Airline: string (nullable = true)
#  |-- DOT_ID_Operating_Airline: integer (nullable = true)
#  |-- IATA_Code_Operating_Airline: string (nullable = true)
#  |-- Tail_Number: string (nullable = true)
#  |-- Flight_Number_Operating_Airline: integer (nullable = true)
#  |-- OriginAirportID: integer (nullable = true)
#  |-- OriginAirportSeqID: integer (nullable = true)
#  |-- OriginCityMarketID: integer (nullable = true)
#  |-- OriginCityName: string (nullable = true)
#  |-- OriginState: string (nullable = true)
#  |-- OriginStateFips: integer (nullable = true)
#  |-- OriginStateName: string (nullable = true)
#  |-- OriginWac: integer (nullable = true)
#  |-- DestAirportID: integer (nullable = true)
#  |-- DestAirportSeqID: integer (nullable = true)
#  |-- DestCityMarketID: integer (nullable = true)
#  |-- DestCityName: string (nullable = true)
#  |-- DestState: string (nullable = true)
#  |-- DestStateFips: integer (nullable = true)
#  |-- DestStateName: string (nullable = true)
#  |-- DestWac: integer (nullable = true)
#  |-- DepDel15: double (nullable = true)
#  |-- DepartureDelayGroups: double (nullable = true)
#  |-- DepTimeBlk: string (nullable = true)
#  |-- TaxiOut: double (nullable = true)
#  |-- WheelsOff: double (nullable = true)
#  |-- WheelsOn: double (nullable = true)
#  |-- TaxiIn: double (nullable = true)
#  |-- CRSArrTime: integer (nullable = true)
#  |-- ArrDelay: double (nullable = true)
#  |-- ArrDel15: double (nullable = true)
#  |-- ArrivalDelayGroups: double (nullable = true)
#  |-- ArrTimeBlk: string (nullable = true)
#  |-- DistanceGroup: integer (nullable = true)
#  |-- DivAirportLandings: integer (nullable = true)

# %%
# Remover depois, é apenas para conseguir rodar
dataframe_sample = dataframe.sample(fraction=0.2, seed=3)
print(f"Número de linhas no DataFrame Sample: {dataframe_sample.count()}")

# Exibindo algumas informações dos atributos
dataframe_sample.summary().show(truncate=False, vertical=True)
# Out:
# Número de linhas no DataFrame Sample: 815645
# 24/04/30 02:53:12 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# -RECORD 0--------------------------------------------------------------
#  summary                                 | count
#  Airline                                 | 815645
#  Origin                                  | 815645
#  Dest                                    | 815645
#  CRSDepTime                              | 815645
#  DepTime                                 | 791472
#  DepDelayMinutes                         | 791451
#  DepDelay                                | 791451
#  ArrTime                                 | 790749
#  ArrDelayMinutes                         | 788919
#  AirTime                                 | 788919
#  CRSElapsedTime                          | 815645
#  ActualElapsedTime                       | 788919
#  Distance                                | 815645
#  Year                                    | 815645
#  Quarter                                 | 815645
#  Month                                   | 815645
#  DayofMonth                              | 815645
#  DayOfWeek                               | 815645
#  Marketing_Airline_Network               | 815645
#  Operated_or_Branded_Code_Share_Partners | 815645
#  DOT_ID_Marketing_Airline                | 815645
#  IATA_Code_Marketing_Airline             | 815645
#  Flight_Number_Marketing_Airline         | 815645
#  Operating_Airline                       | 815645
#  DOT_ID_Operating_Airline                | 815645
#  IATA_Code_Operating_Airline             | 815645
#  Tail_Number                             | 810165
#  Flight_Number_Operating_Airline         | 815645
#  OriginAirportID                         | 815645
#  OriginAirportSeqID                      | 815645
#  OriginCityMarketID                      | 815645
#  OriginCityName                          | 815645
#  OriginState                             | 815645
#  OriginStateFips                         | 815645
#  OriginStateName                         | 815645
#  OriginWac                               | 815645
#  DestAirportID                           | 815645
#  DestAirportSeqID                        | 815645
#  DestCityMarketID                        | 815645
#  DestCityName                            | 815645
#  DestState                               | 815645
#  DestStateFips                           | 815645
#  DestStateName                           | 815645
#  DestWac                                 | 815645
#  DepDel15                                | 791451
#  DepartureDelayGroups                    | 791451
#  DepTimeBlk                              | 815645
#  TaxiOut                                 | 791061
#  WheelsOff                               | 791061
#  WheelsOn                                | 790749
#  TaxiIn                                  | 790749
#  CRSArrTime                              | 815645
#  ArrDelay                                | 788919
#  ArrDel15                                | 788919
#  ArrivalDelayGroups                      | 788919
#  ArrTimeBlk                              | 815645
#  DistanceGroup                           | 815645
#  DivAirportLandings                      | 815645
# -RECORD 1--------------------------------------------------------------
#  summary                                 | mean
#  Airline                                 | null
#  Origin                                  | null
#  Dest                                    | null
#  CRSDepTime                              | 1329.277740928958
#  DepTime                                 | 1334.017683506176
#  DepDelayMinutes                         | 15.991892107028736
#  DepDelay                                | 13.067639057882294
#  ArrTime                                 | 1457.431140602138
#  ArrDelayMinutes                         | 15.757560662121206
#  AirTime                                 | 111.0240848553527
#  CRSElapsedTime                          | 141.34559397777218
#  ActualElapsedTime                       | 135.8676796984228
#  Distance                                | 797.9755126311079
#  Year                                    | 2022.0
#  Quarter                                 | 1.7401786316350862
#  Month                                   | 4.081900826952903
#  DayofMonth                              | 15.719068957696056
#  DayOfWeek                               | 4.005032826781259
#  Marketing_Airline_Network               | null
#  Operated_or_Branded_Code_Share_Partners | null
#  DOT_ID_Marketing_Airline                | 19830.89288722422
#  IATA_Code_Marketing_Airline             | null
#  Flight_Number_Marketing_Airline         | 2563.87000104212
#  Operating_Airline                       | null
#  DOT_ID_Operating_Airline                | 19991.409685586255
#  IATA_Code_Operating_Airline             | null
#  Tail_Number                             | null
#  Flight_Number_Operating_Airline         | 2563.91807955667
#  OriginAirportID                         | 12660.452574343004
#  OriginAirportSeqID                      | 1266049.0996695866
#  OriginCityMarketID                      | 31756.46335722036
#  OriginCityName                          | null
#  OriginState                             | null
#  OriginStateFips                         | 27.465407131779145
#  OriginStateName                         | null
#  OriginWac                               | 53.98253774620086
#  DestAirportID                           | 12658.739331449344
#  DestAirportSeqID                        | 1265877.7782344033
#  DestCityMarketID                        | 31756.096443918617
#  DestCityName                            | null
#  DestState                               | null
#  DestStateFips                           | 27.49072206658534
#  DestStateName                           | null
#  DestWac                                 | 54.01553862280772
#  DepDel15                                | 0.218157535968746
#  DepartureDelayGroups                    | 0.21116784235537006
#  DepTimeBlk                              | null
#  TaxiOut                                 | 16.963915551392372
#  WheelsOff                               | 1356.125447974303
#  WheelsOn                                | 1454.762162203177
#  TaxiIn                                  | 7.891473779922579
#  CRSArrTime                              | 1485.573398966462
#  ArrDelay                                | 7.492845273088872
#  ArrDel15                                | 0.21602090962443546
#  ArrivalDelayGroups                      | -0.06602832483436195
#  ArrTimeBlk                              | null
#  DistanceGroup                           | 3.663456528269039
#  DivAirportLandings                      | 0.003588571008220488
# -RECORD 2--------------------------------------------------------------
#  summary                                 | stddev
#  Airline                                 | null
#  Origin                                  | null
#  Dest                                    | null
#  CRSDepTime                              | 490.7125761921896
#  DepTime                                 | 505.69853460697317
#  DepDelayMinutes                         | 52.584226334012875
#  DepDelay                                | 53.5830654097241
#  ArrTime                                 | 542.867968841562
#  ArrDelayMinutes                         | 52.266871959115974
#  AirTime                                 | 70.07837567439125
#  CRSElapsedTime                          | 71.92692829367716
#  ActualElapsedTime                       | 71.97539708348879
#  Distance                                | 592.5461953030892
#  Year                                    | 0.0
#  Quarter                                 | 0.7031757115379836
#  Month                                   | 1.9983867772749266
#  DayofMonth                              | 8.762510783528704
#  DayOfWeek                               | 2.0083759329192152
#  Marketing_Airline_Network               | null
#  Operated_or_Branded_Code_Share_Partners | null
#  DOT_ID_Marketing_Airline                | 275.72880648781523
#  IATA_Code_Marketing_Airline             | null
#  Flight_Number_Marketing_Airline         | 1746.0588898354438
#  Operating_Airline                       | null
#  DOT_ID_Operating_Airline                | 376.67061949048843
#  IATA_Code_Operating_Airline             | null
#  Tail_Number                             | null
#  Flight_Number_Operating_Airline         | 1746.125920657547
#  OriginAirportID                         | 1522.73998789362
#  OriginAirportSeqID                      | 152273.8009036745
#  OriginCityMarketID                      | 1321.485070710371
#  OriginCityName                          | null
#  OriginState                             | null
#  OriginStateFips                         | 16.7078254202825
#  OriginStateName                         | null
#  OriginWac                               | 26.636641155661035
#  DestAirportID                           | 1522.2484383721448
#  DestAirportSeqID                        | 152224.64867956002
#  DestCityMarketID                        | 1319.8301788677736
#  DestCityName                            | null
#  DestState                               | null
#  DestStateFips                           | 16.71177068035784
#  DestStateName                           | null
#  DestWac                                 | 26.64785646941035
#  DepDel15                                | 0.4129952069674403
#  DepartureDelayGroups                    | 2.3399614222346203
#  DepTimeBlk                              | null
#  TaxiOut                                 | 9.48220625397073
#  WheelsOff                               | 507.67868401551556
#  WheelsOn                                | 537.4499900243842
#  TaxiIn                                  | 6.649904360863729
#  CRSArrTime                              | 518.320251809353
#  ArrDelay                                | 55.511972844533126
#  ArrDel15                                | 0.41152896726476984
#  ArrivalDelayGroups                      | 2.481791888215972
#  ArrTimeBlk                              | null
#  DistanceGroup                           | 2.3227158926482168
#  DivAirportLandings                      | 0.10997326858411804
# -RECORD 3--------------------------------------------------------------
#  summary                                 | min
#  Airline                                 | Air Wisconsin Airlines Corp
#  Origin                                  | ABE
#  Dest                                    | ABE
#  CRSDepTime                              | 1
#  DepTime                                 | 1.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -43.0
#  ArrTime                                 | 1.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 8.0
#  CRSElapsedTime                          | -48.0
#  ActualElapsedTime                       | 16.0
#  Distance                                | 31.0
#  Year                                    | 2022
#  Quarter                                 | 1
#  Month                                   | 1
#  DayofMonth                              | 1
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | AA
#  Operated_or_Branded_Code_Share_Partners | AA
#  DOT_ID_Marketing_Airline                | 19393
#  IATA_Code_Marketing_Airline             | AA
#  Flight_Number_Marketing_Airline         | 1
#  Operating_Airline                       | 9E
#  DOT_ID_Operating_Airline                | 19393
#  IATA_Code_Operating_Airline             | 9E
#  Tail_Number                             | 202NV
#  Flight_Number_Operating_Airline         | 1
#  OriginAirportID                         | 10135
#  OriginAirportSeqID                      | 1013506
#  OriginCityMarketID                      | 30070
#  OriginCityName                          | Aberdeen, SD
#  OriginState                             | AK
#  OriginStateFips                         | 1
#  OriginStateName                         | Alabama
#  OriginWac                               | 1
#  DestAirportID                           | 10135
#  DestAirportSeqID                        | 1013506
#  DestCityMarketID                        | 30070
#  DestCityName                            | Aberdeen, SD
#  DestState                               | AK
#  DestStateFips                           | 1
#  DestStateName                           | Alabama
#  DestWac                                 | 1
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -2.0
#  DepTimeBlk                              | 0001-0559
#  TaxiOut                                 | 1.0
#  WheelsOff                               | 1.0
#  WheelsOn                                | 1.0
#  TaxiIn                                  | 1.0
#  CRSArrTime                              | 1
#  ArrDelay                                | -81.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -2.0
#  ArrTimeBlk                              | 0001-0559
#  DistanceGroup                           | 1
#  DivAirportLandings                      | 0
# -RECORD 4--------------------------------------------------------------
#  summary                                 | 25%
#  Airline                                 | null
#  Origin                                  | null
#  Dest                                    | null
#  CRSDepTime                              | 913
#  DepTime                                 | 917.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -5.0
#  ArrTime                                 | 1046.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 60.0
#  CRSElapsedTime                          | 89.0
#  ActualElapsedTime                       | 83.0
#  Distance                                | 366.0
#  Year                                    | 2022
#  Quarter                                 | 1
#  Month                                   | 2
#  DayofMonth                              | 8
#  DayOfWeek                               | 2
#  Marketing_Airline_Network               | null
#  Operated_or_Branded_Code_Share_Partners | null
#  DOT_ID_Marketing_Airline                | 19790
#  IATA_Code_Marketing_Airline             | null
#  Flight_Number_Marketing_Airline         | 1107
#  Operating_Airline                       | null
#  DOT_ID_Operating_Airline                | 19790
#  IATA_Code_Operating_Airline             | null
#  Tail_Number                             | null
#  Flight_Number_Operating_Airline         | 1107
#  OriginAirportID                         | 11292
#  OriginAirportSeqID                      | 1129202
#  OriginCityMarketID                      | 30693
#  OriginCityName                          | null
#  OriginState                             | null
#  OriginStateFips                         | 12
#  OriginStateName                         | null
#  OriginWac                               | 33
#  DestAirportID                           | 11292
#  DestAirportSeqID                        | 1129202
#  DestCityMarketID                        | 30693
#  DestCityName                            | null
#  DestState                               | null
#  DestStateFips                           | 12
#  DestStateName                           | null
#  DestWac                                 | 33
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | null
#  TaxiOut                                 | 11.0
#  WheelsOff                               | 932.0
#  WheelsOn                                | 1043.0
#  TaxiIn                                  | 4.0
#  CRSArrTime                              | 1102
#  ArrDelay                                | -14.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -1.0
#  ArrTimeBlk                              | null
#  DistanceGroup                           | 2
#  DivAirportLandings                      | 0
# -RECORD 5--------------------------------------------------------------
#  summary                                 | 50%
#  Airline                                 | null
#  Origin                                  | null
#  Dest                                    | null
#  CRSDepTime                              | 1320
#  DepTime                                 | 1325.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -2.0
#  ArrTime                                 | 1459.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 93.0
#  CRSElapsedTime                          | 124.0
#  ActualElapsedTime                       | 119.0
#  Distance                                | 642.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 16
#  DayOfWeek                               | 4
#  Marketing_Airline_Network               | null
#  Operated_or_Branded_Code_Share_Partners | null
#  DOT_ID_Marketing_Airline                | 19805
#  IATA_Code_Marketing_Airline             | null
#  Flight_Number_Marketing_Airline         | 2229
#  Operating_Airline                       | null
#  DOT_ID_Operating_Airline                | 19977
#  IATA_Code_Operating_Airline             | null
#  Tail_Number                             | null
#  Flight_Number_Operating_Airline         | 2229
#  OriginAirportID                         | 12889
#  OriginAirportSeqID                      | 1288903
#  OriginCityMarketID                      | 31453
#  OriginCityName                          | null
#  OriginState                             | null
#  OriginStateFips                         | 27
#  OriginStateName                         | null
#  OriginWac                               | 44
#  DestAirportID                           | 12889
#  DestAirportSeqID                        | 1288903
#  DestCityMarketID                        | 31453
#  DestCityName                            | null
#  DestState                               | null
#  DestStateFips                           | 27
#  DestStateName                           | null
#  DestWac                                 | 44
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | null
#  TaxiOut                                 | 15.0
#  WheelsOff                               | 1338.0
#  WheelsOn                                | 1456.0
#  TaxiIn                                  | 6.0
#  CRSArrTime                              | 1511
#  ArrDelay                                | -5.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -1.0
#  ArrTimeBlk                              | null
#  DistanceGroup                           | 3
#  DivAirportLandings                      | 0
# -RECORD 6--------------------------------------------------------------
#  summary                                 | 75%
#  Airline                                 | null
#  Origin                                  | null
#  Dest                                    | null
#  CRSDepTime                              | 1735
#  DepTime                                 | 1744.0
#  DepDelayMinutes                         | 11.0
#  DepDelay                                | 11.0
#  ArrTime                                 | 1913.0
#  ArrDelayMinutes                         | 10.0
#  AirTime                                 | 141.0
#  CRSElapsedTime                          | 171.0
#  ActualElapsedTime                       | 167.0
#  Distance                                | 1035.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 6
#  DayofMonth                              | 23
#  DayOfWeek                               | 6
#  Marketing_Airline_Network               | null
#  Operated_or_Branded_Code_Share_Partners | null
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | null
#  Flight_Number_Marketing_Airline         | 3881
#  Operating_Airline                       | null
#  DOT_ID_Operating_Airline                | 20378
#  IATA_Code_Operating_Airline             | null
#  Tail_Number                             | null
#  Flight_Number_Operating_Airline         | 3881
#  OriginAirportID                         | 14027
#  OriginAirportSeqID                      | 1402702
#  OriginCityMarketID                      | 32467
#  OriginCityName                          | null
#  OriginState                             | null
#  OriginStateFips                         | 42
#  OriginStateName                         | null
#  OriginWac                               | 81
#  DestAirportID                           | 14027
#  DestAirportSeqID                        | 1402702
#  DestCityMarketID                        | 32467
#  DestCityName                            | null
#  DestState                               | null
#  DestStateFips                           | 42
#  DestStateName                           | null
#  DestWac                                 | 81
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | 0.0
#  DepTimeBlk                              | null
#  TaxiOut                                 | 19.0
#  WheelsOff                               | 1758.0
#  WheelsOn                                | 1909.0
#  TaxiIn                                  | 9.0
#  CRSArrTime                              | 1920
#  ArrDelay                                | 10.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | 0.0
#  ArrTimeBlk                              | null
#  DistanceGroup                           | 5
#  DivAirportLandings                      | 0
# -RECORD 7--------------------------------------------------------------
#  summary                                 | max
#  Airline                                 | United Air Lines Inc.
#  Origin                                  | YUM
#  Dest                                    | YUM
#  CRSDepTime                              | 2359
#  DepTime                                 | 2400.0
#  DepDelayMinutes                         | 5327.0
#  DepDelay                                | 5327.0
#  ArrTime                                 | 2400.0
#  ArrDelayMinutes                         | 5324.0
#  AirTime                                 | 727.0
#  CRSElapsedTime                          | 685.0
#  ActualElapsedTime                       | 764.0
#  Distance                                | 5095.0
#  Year                                    | 2022
#  Quarter                                 | 3
#  Month                                   | 7
#  DayofMonth                              | 31
#  DayOfWeek                               | 7
#  Marketing_Airline_Network               | WN
#  Operated_or_Branded_Code_Share_Partners | WN
#  DOT_ID_Marketing_Airline                | 20436
#  IATA_Code_Marketing_Airline             | WN
#  Flight_Number_Marketing_Airline         | 9678
#  Operating_Airline                       | ZW
#  DOT_ID_Operating_Airline                | 20500
#  IATA_Code_Operating_Airline             | ZW
#  Tail_Number                             | N999JQ
#  Flight_Number_Operating_Airline         | 9678
#  OriginAirportID                         | 16869
#  OriginAirportSeqID                      | 1686901
#  OriginCityMarketID                      | 36101
#  OriginCityName                          | Yuma, AZ
#  OriginState                             | WY
#  OriginStateFips                         | 78
#  OriginStateName                         | Wyoming
#  OriginWac                               | 93
#  DestAirportID                           | 16869
#  DestAirportSeqID                        | 1686901
#  DestCityMarketID                        | 36101
#  DestCityName                            | Yuma, AZ
#  DestState                               | WY
#  DestStateFips                           | 78
#  DestStateName                           | Wyoming
#  DestWac                                 | 93
#  DepDel15                                | 1.0
#  DepartureDelayGroups                    | 12.0
#  DepTimeBlk                              | 2300-2359
#  TaxiOut                                 | 221.0
#  WheelsOff                               | 2400.0
#  WheelsOn                                | 2400.0
#  TaxiIn                                  | 280.0
#  CRSArrTime                              | 2359
#  ArrDelay                                | 5324.0
#  ArrDel15                                | 1.0
#  ArrivalDelayGroups                      | 12.0
#  ArrTimeBlk                              | 2300-2359
#  DistanceGroup                           | 11
#  DivAirportLandings                      | 9

# %%
# Mostrando as primeiras linhas do DataFrame
dataframe.show(n=5, truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------------------
#  FlightDate                              | 2022-04-04 00:00:00
#  Airline                                 | Commutair Aka Champlain Enterprises, Inc.
#  Origin                                  | GJT
#  Dest                                    | DEN
#  Cancelled                               | false
#  Diverted                                | false
#  CRSDepTime                              | 1133
#  DepTime                                 | 1123.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -10.0
#  ArrTime                                 | 1228.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 40.0
#  CRSElapsedTime                          | 72.0
#  ActualElapsedTime                       | 65.0
#  Distance                                | 212.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 4
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | UA
#  Operated_or_Branded_Code_Share_Partners | UA_CODESHARE
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | UA
#  Flight_Number_Marketing_Airline         | 4301
#  Operating_Airline                       | C5
#  DOT_ID_Operating_Airline                | 20445
#  IATA_Code_Operating_Airline             | C5
#  Tail_Number                             | N21144
#  Flight_Number_Operating_Airline         | 4301
#  OriginAirportID                         | 11921
#  OriginAirportSeqID                      | 1192102
#  OriginCityMarketID                      | 31921
#  OriginCityName                          | Grand Junction, CO
#  OriginState                             | CO
#  OriginStateFips                         | 8
#  OriginStateName                         | Colorado
#  OriginWac                               | 82
#  DestAirportID                           | 11292
#  DestAirportSeqID                        | 1129202
#  DestCityMarketID                        | 30325
#  DestCityName                            | Denver, CO
#  DestState                               | CO
#  DestStateFips                           | 8
#  DestStateName                           | Colorado
#  DestWac                                 | 82
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | 1100-1159
#  TaxiOut                                 | 17.0
#  WheelsOff                               | 1140.0
#  WheelsOn                                | 1220.0
#  TaxiIn                                  | 8.0
#  CRSArrTime                              | 1245
#  ArrDelay                                | -17.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -2.0
#  ArrTimeBlk                              | 1200-1259
#  DistanceGroup                           | 1
#  DivAirportLandings                      | 0
# -RECORD 1----------------------------------------------------------------------------
#  FlightDate                              | 2022-04-04 00:00:00
#  Airline                                 | Commutair Aka Champlain Enterprises, Inc.
#  Origin                                  | HRL
#  Dest                                    | IAH
#  Cancelled                               | false
#  Diverted                                | false
#  CRSDepTime                              | 732
#  DepTime                                 | 728.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -4.0
#  ArrTime                                 | 848.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 55.0
#  CRSElapsedTime                          | 77.0
#  ActualElapsedTime                       | 80.0
#  Distance                                | 295.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 4
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | UA
#  Operated_or_Branded_Code_Share_Partners | UA_CODESHARE
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | UA
#  Flight_Number_Marketing_Airline         | 4299
#  Operating_Airline                       | C5
#  DOT_ID_Operating_Airline                | 20445
#  IATA_Code_Operating_Airline             | C5
#  Tail_Number                             | N16170
#  Flight_Number_Operating_Airline         | 4299
#  OriginAirportID                         | 12206
#  OriginAirportSeqID                      | 1220605
#  OriginCityMarketID                      | 32206
#  OriginCityName                          | Harlingen/San Benito, TX
#  OriginState                             | TX
#  OriginStateFips                         | 48
#  OriginStateName                         | Texas
#  OriginWac                               | 74
#  DestAirportID                           | 12266
#  DestAirportSeqID                        | 1226603
#  DestCityMarketID                        | 31453
#  DestCityName                            | Houston, TX
#  DestState                               | TX
#  DestStateFips                           | 48
#  DestStateName                           | Texas
#  DestWac                                 | 74
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | 0700-0759
#  TaxiOut                                 | 16.0
#  WheelsOff                               | 744.0
#  WheelsOn                                | 839.0
#  TaxiIn                                  | 9.0
#  CRSArrTime                              | 849
#  ArrDelay                                | -1.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -1.0
#  ArrTimeBlk                              | 0800-0859
#  DistanceGroup                           | 2
#  DivAirportLandings                      | 0
# -RECORD 2----------------------------------------------------------------------------
#  FlightDate                              | 2022-04-04 00:00:00
#  Airline                                 | Commutair Aka Champlain Enterprises, Inc.
#  Origin                                  | DRO
#  Dest                                    | DEN
#  Cancelled                               | false
#  Diverted                                | false
#  CRSDepTime                              | 1529
#  DepTime                                 | 1514.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -15.0
#  ArrTime                                 | 1636.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 47.0
#  CRSElapsedTime                          | 70.0
#  ActualElapsedTime                       | 82.0
#  Distance                                | 251.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 4
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | UA
#  Operated_or_Branded_Code_Share_Partners | UA_CODESHARE
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | UA
#  Flight_Number_Marketing_Airline         | 4298
#  Operating_Airline                       | C5
#  DOT_ID_Operating_Airline                | 20445
#  IATA_Code_Operating_Airline             | C5
#  Tail_Number                             | N21144
#  Flight_Number_Operating_Airline         | 4298
#  OriginAirportID                         | 11413
#  OriginAirportSeqID                      | 1141307
#  OriginCityMarketID                      | 30285
#  OriginCityName                          | Durango, CO
#  OriginState                             | CO
#  OriginStateFips                         | 8
#  OriginStateName                         | Colorado
#  OriginWac                               | 82
#  DestAirportID                           | 11292
#  DestAirportSeqID                        | 1129202
#  DestCityMarketID                        | 30325
#  DestCityName                            | Denver, CO
#  DestState                               | CO
#  DestStateFips                           | 8
#  DestStateName                           | Colorado
#  DestWac                                 | 82
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | 1500-1559
#  TaxiOut                                 | 21.0
#  WheelsOff                               | 1535.0
#  WheelsOn                                | 1622.0
#  TaxiIn                                  | 14.0
#  CRSArrTime                              | 1639
#  ArrDelay                                | -3.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -1.0
#  ArrTimeBlk                              | 1600-1659
#  DistanceGroup                           | 2
#  DivAirportLandings                      | 0
# -RECORD 3----------------------------------------------------------------------------
#  FlightDate                              | 2022-04-04 00:00:00
#  Airline                                 | Commutair Aka Champlain Enterprises, Inc.
#  Origin                                  | IAH
#  Dest                                    | GPT
#  Cancelled                               | false
#  Diverted                                | false
#  CRSDepTime                              | 1435
#  DepTime                                 | 1430.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | -5.0
#  ArrTime                                 | 1547.0
#  ArrDelayMinutes                         | 0.0
#  AirTime                                 | 57.0
#  CRSElapsedTime                          | 90.0
#  ActualElapsedTime                       | 77.0
#  Distance                                | 376.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 4
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | UA
#  Operated_or_Branded_Code_Share_Partners | UA_CODESHARE
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | UA
#  Flight_Number_Marketing_Airline         | 4296
#  Operating_Airline                       | C5
#  DOT_ID_Operating_Airline                | 20445
#  IATA_Code_Operating_Airline             | C5
#  Tail_Number                             | N11184
#  Flight_Number_Operating_Airline         | 4296
#  OriginAirportID                         | 12266
#  OriginAirportSeqID                      | 1226603
#  OriginCityMarketID                      | 31453
#  OriginCityName                          | Houston, TX
#  OriginState                             | TX
#  OriginStateFips                         | 48
#  OriginStateName                         | Texas
#  OriginWac                               | 74
#  DestAirportID                           | 11973
#  DestAirportSeqID                        | 1197302
#  DestCityMarketID                        | 31973
#  DestCityName                            | Gulfport/Biloxi, MS
#  DestState                               | MS
#  DestStateFips                           | 28
#  DestStateName                           | Mississippi
#  DestWac                                 | 53
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | -1.0
#  DepTimeBlk                              | 1400-1459
#  TaxiOut                                 | 16.0
#  WheelsOff                               | 1446.0
#  WheelsOn                                | 1543.0
#  TaxiIn                                  | 4.0
#  CRSArrTime                              | 1605
#  ArrDelay                                | -18.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | -2.0
#  ArrTimeBlk                              | 1600-1659
#  DistanceGroup                           | 2
#  DivAirportLandings                      | 0
# -RECORD 4----------------------------------------------------------------------------
#  FlightDate                              | 2022-04-04 00:00:00
#  Airline                                 | Commutair Aka Champlain Enterprises, Inc.
#  Origin                                  | DRO
#  Dest                                    | DEN
#  Cancelled                               | false
#  Diverted                                | false
#  CRSDepTime                              | 1135
#  DepTime                                 | 1135.0
#  DepDelayMinutes                         | 0.0
#  DepDelay                                | 0.0
#  ArrTime                                 | 1251.0
#  ArrDelayMinutes                         | 6.0
#  AirTime                                 | 49.0
#  CRSElapsedTime                          | 70.0
#  ActualElapsedTime                       | 76.0
#  Distance                                | 251.0
#  Year                                    | 2022
#  Quarter                                 | 2
#  Month                                   | 4
#  DayofMonth                              | 4
#  DayOfWeek                               | 1
#  Marketing_Airline_Network               | UA
#  Operated_or_Branded_Code_Share_Partners | UA_CODESHARE
#  DOT_ID_Marketing_Airline                | 19977
#  IATA_Code_Marketing_Airline             | UA
#  Flight_Number_Marketing_Airline         | 4295
#  Operating_Airline                       | C5
#  DOT_ID_Operating_Airline                | 20445
#  IATA_Code_Operating_Airline             | C5
#  Tail_Number                             | N17146
#  Flight_Number_Operating_Airline         | 4295
#  OriginAirportID                         | 11413
#  OriginAirportSeqID                      | 1141307
#  OriginCityMarketID                      | 30285
#  OriginCityName                          | Durango, CO
#  OriginState                             | CO
#  OriginStateFips                         | 8
#  OriginStateName                         | Colorado
#  OriginWac                               | 82
#  DestAirportID                           | 11292
#  DestAirportSeqID                        | 1129202
#  DestCityMarketID                        | 30325
#  DestCityName                            | Denver, CO
#  DestState                               | CO
#  DestStateFips                           | 8
#  DestStateName                           | Colorado
#  DestWac                                 | 82
#  DepDel15                                | 0.0
#  DepartureDelayGroups                    | 0.0
#  DepTimeBlk                              | 1100-1159
#  TaxiOut                                 | 19.0
#  WheelsOff                               | 1154.0
#  WheelsOn                                | 1243.0
#  TaxiIn                                  | 8.0
#  CRSArrTime                              | 1245
#  ArrDelay                                | 6.0
#  ArrDel15                                | 0.0
#  ArrivalDelayGroups                      | 0.0
#  ArrTimeBlk                              | 1200-1259
#  DistanceGroup                           | 2
#  DivAirportLandings                      | 0
# only showing top 5 rows

# %%
# Checagem por dados nulos
Dict_Null = {col:dataframe_sample.filter(dataframe_sample[col].isNull()).count() for col in dataframe_sample.columns}
Dict_Null
# Out:
# {'FlightDate': 0,
#  'Airline': 0,
#  'Origin': 0,
#  'Dest': 0,
#  'Cancelled': 0,
#  'Diverted': 0,
#  'CRSDepTime': 0,
#  'DepTime': 24173,
#  'DepDelayMinutes': 24194,
#  'DepDelay': 24194,
#  'ArrTime': 24896,
#  'ArrDelayMinutes': 26726,
#  'AirTime': 26726,
#  'CRSElapsedTime': 0,
#  'ActualElapsedTime': 26726,
#  'Distance': 0,
#  'Year': 0,
#  'Quarter': 0,
#  'Month': 0,
#  'DayofMonth': 0,
#  'DayOfWeek': 0,
#  'Marketing_Airline_Network': 0,
#  'Operated_or_Branded_Code_Share_Partners': 0,
#  'DOT_ID_Marketing_Airline': 0,
#  'IATA_Code_Marketing_Airline': 0,
#  'Flight_Number_Marketing_Airline': 0,
#  'Operating_Airline': 0,
#  'DOT_ID_Operating_Airline': 0,
#  'IATA_Code_Operating_Airline': 0,
#  'Tail_Number': 5480,
#  'Flight_Number_Operating_Airline': 0,
#  'OriginAirportID': 0,
#  'OriginAirportSeqID': 0,
#  'OriginCityMarketID': 0,
#  'OriginCityName': 0,
#  'OriginState': 0,
#  'OriginStateFips': 0,
#  'OriginStateName': 0,
#  'OriginWac': 0,
#  'DestAirportID': 0,
#  'DestAirportSeqID': 0,
#  'DestCityMarketID': 0,
#  'DestCityName': 0,
#  'DestState': 0,
#  'DestStateFips': 0,
#  'DestStateName': 0,
#  'DestWac': 0,
#  'DepDel15': 24194,
#  'DepartureDelayGroups': 24194,
#  'DepTimeBlk': 0,
#  'TaxiOut': 24584,
#  'WheelsOff': 24584,
#  'WheelsOn': 24896,
#  'TaxiIn': 24896,
#  'CRSArrTime': 0,
#  'ArrDelay': 26726,
#  'ArrDel15': 26726,
#  'ArrivalDelayGroups': 26726,
#  'ArrTimeBlk': 0,
#  'DistanceGroup': 0,
#  'DivAirportLandings': 0}

# %% [markdown]
# Pudemos visualizar que existem alguns dados nulos principalmente nas colunas referentes ao tempo de viagem, como o delay na partida ou chegada e tempo de voo.

# %% [markdown]
# ## Pré-processamento

# %%
# Remover colunas de ID e nome do DataFrame
colunas_para_remover = [
    'DOT_ID_Marketing_Airline', 'DOT_ID_Operating_Airline', 
    'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 
    'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
    'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline', 'IATA_Code_Operating_Airline', 'Tail_Number', 'Flight_Number_Operating_Airline', 'Airline',
    'Origin',
    'Dest',
    'Marketing_Airline_Network',
    'Operated_or_Branded_Code_Share_Partners',
    'Operating_Airline',
    'OriginCityName',
    'OriginState',
    'OriginStateName',
    'DestCityName',
    'DestState',
    'DestStateName',
    'DepTimeBlk',
    'ArrTimeBlk',
    'FlightDate'
]

dataframe_sem_colunas_de_id = dataframe_sample.drop(*colunas_para_remover)

# Mostrar somente o nome das colunas
print("Nome das colunas:")
for coluna in dataframe_sem_colunas_de_id.columns:
    print(coluna)
# Out:
# Nome das colunas:
# Cancelled
# Diverted
# CRSDepTime
# DepTime
# DepDelayMinutes
# DepDelay
# ArrTime
# ArrDelayMinutes
# AirTime
# CRSElapsedTime
# ActualElapsedTime
# Distance
# Year
# Quarter
# Month
# DayofMonth
# DayOfWeek
# OriginStateFips
# OriginWac
# DestStateFips
# DestWac
# DepDel15
# DepartureDelayGroups
# TaxiOut
# WheelsOff
# WheelsOn
# TaxiIn
# CRSArrTime
# ArrDelay
# ArrDel15
# ArrivalDelayGroups
# DistanceGroup
# DivAirportLandings

# %%
# Tratando valores nulos
dataframe_sem_valores_nulos = dataframe_sem_colunas_de_id.dropna()

# Correlação
assembler = VectorAssembler(inputCols=dataframe_sem_valores_nulos.columns, outputCol="features")
dataframe_vetorizado = assembler.transform(dataframe_sem_valores_nulos)

correlation = Correlation.corr(dataframe_vetorizado, "features", method="pearson").collect()[0][0]

rows = correlation.toArray().tolist()
spark.createDataFrame(rows,dataframe_sem_valores_nulos.columns).show(n=30, truncate=False, vertical=True)
# Out:
# [Stage 199:>                                                      (0 + 16) / 16]
# 24/04/30 02:58:39 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/30 02:58:39 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.ForeignLinkerBLAS
# 24/04/30 02:58:43 WARN PearsonCorrelation: Pearson correlation matrix contains NaN values.
# -RECORD 0--------------------------------------
#  Cancelled            | 1.0
#  Diverted             | NaN
#  CRSDepTime           | NaN
#  DepTime              | NaN
#  DepDelayMinutes      | NaN
#  DepDelay             | NaN
#  ArrTime              | NaN
#  ArrDelayMinutes      | NaN
#  AirTime              | NaN
#  CRSElapsedTime       | NaN
#  ActualElapsedTime    | NaN
#  Distance             | NaN
#  Year                 | NaN
#  Quarter              | NaN
#  Month                | NaN
#  DayofMonth           | NaN
#  DayOfWeek            | NaN
#  OriginStateFips      | NaN
#  OriginWac            | NaN
#  DestStateFips        | NaN
#  DestWac              | NaN
#  DepDel15             | NaN
#  DepartureDelayGroups | NaN
#  TaxiOut              | NaN
#  WheelsOff            | NaN
#  WheelsOn             | NaN
#  TaxiIn               | NaN
#  CRSArrTime           | NaN
#  ArrDelay             | NaN
#  ArrDel15             | NaN
#  ArrivalDelayGroups   | NaN
#  DistanceGroup        | NaN
#  DivAirportLandings   | NaN
# -RECORD 1--------------------------------------
#  Cancelled            | NaN
#  Diverted             | 1.0
#  CRSDepTime           | NaN
#  DepTime              | NaN
#  DepDelayMinutes      | NaN
#  DepDelay             | NaN
#  ArrTime              | NaN
#  ArrDelayMinutes      | NaN
#  AirTime              | NaN
#  CRSElapsedTime       | NaN
#  ActualElapsedTime    | NaN
#  Distance             | NaN
#  Year                 | NaN
#  Quarter              | NaN
#  Month                | NaN
#  DayofMonth           | NaN
#  DayOfWeek            | NaN
#  OriginStateFips      | NaN
#  OriginWac            | NaN
#  DestStateFips        | NaN
#  DestWac              | NaN
#  DepDel15             | NaN
#  DepartureDelayGroups | NaN
#  TaxiOut              | NaN
#  WheelsOff            | NaN
#  WheelsOn             | NaN
#  TaxiIn               | NaN
#  CRSArrTime           | NaN
#  ArrDelay             | NaN
#  ArrDel15             | NaN
#  ArrivalDelayGroups   | NaN
#  DistanceGroup        | NaN
#  DivAirportLandings   | NaN
# -RECORD 2--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 1.0
#  DepTime              | 0.9459648328151701
#  DepDelayMinutes      | 0.09286911787484042
#  DepDelay             | 0.09912591069827202
#  ArrTime              | 0.572843299932981
#  ArrDelayMinutes      | 0.08342026121484372
#  AirTime              | -0.009357181422049297
#  CRSElapsedTime       | -0.014046344867286478
#  ActualElapsedTime    | -0.011146852786503701
#  Distance             | -0.002688275977139366
#  Year                 | NaN
#  Quarter              | 0.0044183144489564315
#  Month                | 0.00524733090314301
#  DayofMonth           | -9.979210338216616E-5
#  DayOfWeek            | 0.004984452898119005
#  OriginStateFips      | -0.014060136649506113
#  OriginWac            | -0.0061586629001304525
#  DestStateFips        | 0.00917158250950291
#  DestWac              | 0.018385717292485823
#  DepDel15             | 0.18518275728484054
#  DepartureDelayGroups | 0.1472672240944412
#  TaxiOut              | -9.956782710744342E-4
#  WheelsOff            | 0.9151107135981389
#  WheelsOn             | 0.6079684001209741
#  TaxiIn               | -0.020649406906719393
#  CRSArrTime           | 0.6858336434166958
#  ArrDelay             | 0.09929260516875582
#  ArrDel15             | 0.1599517809077912
#  ArrivalDelayGroups   | 0.13734511288516565
#  DistanceGroup        | -0.0036225036978557675
#  DivAirportLandings   | NaN
# -RECORD 3--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.9459648328151701
#  DepTime              | 1.0
#  DepDelayMinutes      | 0.11568921275599105
#  DepDelay             | 0.12356188980098515
#  ArrTime              | 0.6036213015687809
#  ArrDelayMinutes      | 0.10610734136399522
#  AirTime              | -0.016463346879464248
#  CRSElapsedTime       | -0.021157705874214713
#  ActualElapsedTime    | -0.01662934360917353
#  Distance             | -0.01294909874098756
#  Year                 | NaN
#  Quarter              | 0.003958024099489536
#  Month                | 0.004622519713885499
#  DayofMonth           | -0.0018170502850000405
#  DayOfWeek            | 0.007429539519528246
#  OriginStateFips      | -0.009515190006684104
#  OriginWac            | -0.013343583097882765
#  DestStateFips        | 0.00631947737159933
#  DestWac              | 0.02190488436616467
#  DepDel15             | 0.23013527010175533
#  DepartureDelayGroups | 0.19861727153156805
#  TaxiOut              | 0.008108219136773984
#  WheelsOff            | 0.9668895776479303
#  WheelsOn             | 0.6400283014894176
#  TaxiIn               | -0.01806358546682881
#  CRSArrTime           | 0.691165431303141
#  ArrDelay             | 0.12495610950226806
#  ArrDel15             | 0.20126609641306747
#  ArrivalDelayGroups   | 0.18703836438881433
#  DistanceGroup        | -0.013919813960131299
#  DivAirportLandings   | NaN
# -RECORD 4--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.09286911787484042
#  DepTime              | 0.11568921275599105
#  DepDelayMinutes      | 1.0
#  DepDelay             | 0.9979471272080763
#  ArrTime              | 0.013144269505034261
#  ArrDelayMinutes      | 0.9807391025650322
#  AirTime              | 0.015893815536272435
#  CRSElapsedTime       | 0.018148484462922984
#  ActualElapsedTime    | 0.0224925345170426
#  Distance             | 0.016038963610055145
#  Year                 | NaN
#  Quarter              | 0.020817896803759582
#  Month                | 0.024381425973401365
#  DayofMonth           | -0.012049551993937455
#  DayOfWeek            | 0.029151057333275485
#  OriginStateFips      | 0.002690913873687306
#  OriginWac            | -0.029049398071184087
#  DestStateFips        | 0.0034141566542855925
#  DestWac              | -0.027123778263731337
#  DepDel15             | 0.5251556922679033
#  DepartureDelayGroups | 0.8046288044527046
#  TaxiOut              | 0.04286500685342134
#  WheelsOff            | 0.10646033393682264
#  WheelsOn             | 0.019842656598162502
#  TaxiIn               | 0.014933658582335857
#  CRSArrTime           | 0.07015220254070503
#  ArrDelay             | 0.9669400574964583
#  ArrDel15             | 0.49173128111726633
#  ArrivalDelayGroups   | 0.7597272456210225
#  DistanceGroup        | 0.0169115048168837
#  DivAirportLandings   | NaN
# -RECORD 5--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.09912591069827202
#  DepTime              | 0.12356188980098515
#  DepDelayMinutes      | 0.9979471272080763
#  DepDelay             | 1.0
#  ArrTime              | 0.017970258422984754
#  ArrDelayMinutes      | 0.9775427370001296
#  AirTime              | 0.02108172593460725
#  CRSElapsedTime       | 0.022964053299411546
#  ActualElapsedTime    | 0.02718361507673257
#  Distance             | 0.021612576519574767
#  Year                 | NaN
#  Quarter              | 0.023520494467968184
#  Month                | 0.028188729928695637
#  DayofMonth           | -0.012384583289091252
#  DayOfWeek            | 0.03196144196615611
#  OriginStateFips      | 5.862078910940324E-5
#  OriginWac            | -0.026139099533031805
#  DestStateFips        | 7.511778173493388E-4
#  DestWac              | -0.0244830144464333
#  DepDel15             | 0.544223571721839
#  DepartureDelayGroups | 0.8184852451518922
#  TaxiOut              | 0.042875764206242825
#  WheelsOff            | 0.11404069369085368
#  WheelsOn             | 0.02521768174878014
#  TaxiIn               | 0.011015594386533831
#  CRSArrTime           | 0.07528798873696223
#  ArrDelay             | 0.9687443897554385
#  ArrDel15             | 0.507379721864141
#  ArrivalDelayGroups   | 0.7715913518538431
#  DistanceGroup        | 0.022467706562220944
#  DivAirportLandings   | NaN
# -RECORD 6--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.572843299932981
#  DepTime              | 0.6036213015687809
#  DepDelayMinutes      | 0.013144269505034261
#  DepDelay             | 0.017970258422984754
#  ArrTime              | 1.0
#  ArrDelayMinutes      | 0.014267732451942499
#  AirTime              | 0.013519675626259327
#  CRSElapsedTime       | 0.010235409831335225
#  ActualElapsedTime    | 0.017573835421323937
#  Distance             | 0.008451754758541302
#  Year                 | NaN
#  Quarter              | -0.019191971593957753
#  Month                | -0.022688469246338328
#  DayofMonth           | -0.0017396513047987056
#  DayOfWeek            | 1.648431657137716E-4
#  OriginStateFips      | -0.0020779401832956295
#  OriginWac            | 0.008221707898049784
#  DestStateFips        | 0.013069789262640715
#  DestWac              | 0.02054784079383739
#  DepDel15             | 0.0845557499401606
#  DepartureDelayGroups | 0.04302725883749446
#  TaxiOut              | 0.02554407377590659
#  WheelsOff            | 0.6268205905312795
#  WheelsOn             | 0.9581516472798329
#  TaxiIn               | 0.011377052191596971
#  CRSArrTime           | 0.8206870695163324
#  ArrDelay             | 0.026805820200931838
#  ArrDel15             | 0.0763319394300748
#  ArrivalDelayGroups   | 0.04897797668858172
#  DistanceGroup        | 0.011420145292840038
#  DivAirportLandings   | NaN
# -RECORD 7--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.08342026121484372
#  DepTime              | 0.10610734136399522
#  DepDelayMinutes      | 0.9807391025650322
#  DepDelay             | 0.9775427370001296
#  ArrTime              | 0.014267732451942499
#  ArrDelayMinutes      | 1.0
#  AirTime              | 0.019657639265298933
#  CRSElapsedTime       | 0.012014093461934489
#  ActualElapsedTime    | 0.04653366772812545
#  Distance             | 0.01075030148964973
#  Year                 | NaN
#  Quarter              | 0.019553716214806175
#  Month                | 0.023061837300170435
#  DayofMonth           | -0.012668800299420935
#  DayOfWeek            | 0.028403939408936374
#  OriginStateFips      | 0.00636070456903408
#  OriginWac            | -0.03629811414103378
#  DestStateFips        | 0.005776974177521961
#  DestWac              | -0.03519469196769234
#  DepDel15             | 0.4824071200678222
#  DepartureDelayGroups | 0.7740185403751902
#  TaxiOut              | 0.14716457600847246
#  WheelsOff            | 0.10017256177453779
#  WheelsOn             | 0.021065876118400585
#  TaxiIn               | 0.08705146687941728
#  CRSArrTime           | 0.06715136809533924
#  ArrDelay             | 0.986427638822554
#  ArrDel15             | 0.5257058262060397
#  ArrivalDelayGroups   | 0.7871897119285365
#  DistanceGroup        | 0.011654386679457123
#  DivAirportLandings   | NaN
# -RECORD 8--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.009357181422049297
#  DepTime              | -0.016463346879464248
#  DepDelayMinutes      | 0.015893815536272435
#  DepDelay             | 0.02108172593460725
#  ArrTime              | 0.013519675626259327
#  ArrDelayMinutes      | 0.019657639265298933
#  AirTime              | 1.0
#  CRSElapsedTime       | 0.989505917430485
#  ActualElapsedTime    | 0.9869064964918559
#  Distance             | 0.9849768904354144
#  Year                 | NaN
#  Quarter              | -0.015339696543211311
#  Month                | -0.01675890855051634
#  DayofMonth           | -0.004775242124156686
#  DayOfWeek            | 0.007925780391683597
#  OriginStateFips      | -0.05598355288155938
#  OriginWac            | -0.023469458374165787
#  DestStateFips        | -0.08504069527197906
#  DestWac              | 0.05831527353517117
#  DepDel15             | 0.03198242240785038
#  DepartureDelayGroups | 0.032079788562542504
#  TaxiOut              | 0.04773170964004704
#  WheelsOff            | -0.02743499343212044
#  WheelsOn             | 0.016479540365156864
#  TaxiIn               | 0.07568193879107349
#  CRSArrTime           | 0.024924868775779888
#  ArrDelay             | 0.014607232851648546
#  ArrDel15             | 0.04452799887998005
#  ArrivalDelayGroups   | 0.025786993373505783
#  DistanceGroup        | 0.9726620496887042
#  DivAirportLandings   | NaN
# -RECORD 9--------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.014046344867286478
#  DepTime              | -0.021157705874214713
#  DepDelayMinutes      | 0.018148484462922984
#  DepDelay             | 0.022964053299411546
#  ArrTime              | 0.010235409831335225
#  ArrDelayMinutes      | 0.012014093461934489
#  AirTime              | 0.989505917430485
#  CRSElapsedTime       | 1.0
#  ActualElapsedTime    | 0.981717565180772
#  Distance             | 0.982287109060917
#  Year                 | NaN
#  Quarter              | -0.02396774918310318
#  Month                | -0.027207337756154172
#  DayofMonth           | -0.00497741426678489
#  DayOfWeek            | 0.007810678923697986
#  OriginStateFips      | -0.04397311629504004
#  OriginWac            | -0.040968748726779435
#  DestStateFips        | -0.0799486050693545
#  DestWac              | 0.04946061118163528
#  DepDel15             | 0.03076696567318076
#  DepartureDelayGroups | 0.03306331590777644
#  TaxiOut              | 0.07329058131418784
#  WheelsOff            | -0.0313325992334599
#  WheelsOn             | 0.012748249491625748
#  TaxiIn               | 0.0937357667284863
#  CRSArrTime           | 0.022708945073579102
#  ArrDelay             | -0.003920446039479076
#  ArrDel15             | 0.021982644986221156
#  ArrivalDelayGroups   | 2.2192731530247805E-5
#  DistanceGroup        | 0.9699913931238291
#  DivAirportLandings   | NaN
# -RECORD 10-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.011146852786503701
#  DepTime              | -0.01662934360917353
#  DepDelayMinutes      | 0.0224925345170426
#  DepDelay             | 0.02718361507673257
#  ArrTime              | 0.017573835421323937
#  ArrDelayMinutes      | 0.04653366772812545
#  AirTime              | 0.9869064964918559
#  CRSElapsedTime       | 0.981717565180772
#  ActualElapsedTime    | 1.0
#  Distance             | 0.9693338720945883
#  Year                 | NaN
#  Quarter              | -0.0173890168245817
#  Month                | -0.019510912405166017
#  DayofMonth           | -0.006172987386611147
#  DayOfWeek            | 0.009559832464337446
#  OriginStateFips      | -0.043449850658032134
#  OriginWac            | -0.04429699857336228
#  DestStateFips        | -0.07695998651583101
#  DestWac              | 0.04097078970379641
#  DepDel15             | 0.035691183789176836
#  DepartureDelayGroups | 0.0390077155959112
#  TaxiOut              | 0.17944144068624684
#  WheelsOff            | -0.023878040618922815
#  WheelsOn             | 0.02075879503138207
#  TaxiIn               | 0.16794742149410224
#  CRSArrTime           | 0.02768476180067025
#  ArrDelay             | 0.04757567716608211
#  ArrDel15             | 0.08709242494615298
#  ArrivalDelayGroups   | 0.07010037113776928
#  DistanceGroup        | 0.9570468023611618
#  DivAirportLandings   | NaN
# -RECORD 11-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.002688275977139366
#  DepTime              | -0.01294909874098756
#  DepDelayMinutes      | 0.016038963610055145
#  DepDelay             | 0.021612576519574767
#  ArrTime              | 0.008451754758541302
#  ArrDelayMinutes      | 0.01075030148964973
#  AirTime              | 0.9849768904354144
#  CRSElapsedTime       | 0.982287109060917
#  ActualElapsedTime    | 0.9693338720945883
#  Distance             | 1.0
#  Year                 | NaN
#  Quarter              | -0.004967353375424438
#  Month                | -0.005633650975211513
#  DayofMonth           | -0.002979639250339895
#  DayOfWeek            | 0.009617717766529633
#  OriginStateFips      | -0.07901956100008559
#  OriginWac            | 0.026457827529463872
#  DestStateFips        | -0.0802470319116144
#  DestWac              | 0.026658972369600024
#  DepDel15             | 0.034081518796314506
#  DepartureDelayGroups | 0.03236767921179807
#  TaxiOut              | 0.030187209375568104
#  WheelsOff            | -0.027199728589956867
#  WheelsOn             | 0.01192492353764605
#  TaxiIn               | 0.06877634433801308
#  CRSArrTime           | 0.02160125094268319
#  ArrDelay             | 0.0017111142667811839
#  ArrDel15             | 0.026769883173506773
#  ArrivalDelayGroups   | 0.00712369729203335
#  DistanceGroup        | 0.9860637221935258
#  DivAirportLandings   | NaN
# -RECORD 12-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | NaN
#  DepTime              | NaN
#  DepDelayMinutes      | NaN
#  DepDelay             | NaN
#  ArrTime              | NaN
#  ArrDelayMinutes      | NaN
#  AirTime              | NaN
#  CRSElapsedTime       | NaN
#  ActualElapsedTime    | NaN
#  Distance             | NaN
#  Year                 | 1.0
#  Quarter              | NaN
#  Month                | NaN
#  DayofMonth           | NaN
#  DayOfWeek            | NaN
#  OriginStateFips      | NaN
#  OriginWac            | NaN
#  DestStateFips        | NaN
#  DestWac              | NaN
#  DepDel15             | NaN
#  DepartureDelayGroups | NaN
#  TaxiOut              | NaN
#  WheelsOff            | NaN
#  WheelsOn             | NaN
#  TaxiIn               | NaN
#  CRSArrTime           | NaN
#  ArrDelay             | NaN
#  ArrDel15             | NaN
#  ArrivalDelayGroups   | NaN
#  DistanceGroup        | NaN
#  DivAirportLandings   | NaN
# -RECORD 13-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.0044183144489564315
#  DepTime              | 0.003958024099489536
#  DepDelayMinutes      | 0.020817896803759582
#  DepDelay             | 0.023520494467968184
#  ArrTime              | -0.019191971593957753
#  ArrDelayMinutes      | 0.019553716214806175
#  AirTime              | -0.015339696543211311
#  CRSElapsedTime       | -0.02396774918310318
#  ActualElapsedTime    | -0.0173890168245817
#  Distance             | -0.004967353375424438
#  Year                 | NaN
#  Quarter              | 1.0
#  Month                | 0.9175613064300949
#  DayofMonth           | 0.009165747744492832
#  DayOfWeek            | 0.03381206314631074
#  OriginStateFips      | 0.003561649391763457
#  OriginWac            | 0.007998291037122277
#  DestStateFips        | 0.006791348036619248
#  DestWac              | 0.008532132475068318
#  DepDel15             | 0.03299390449608576
#  DepartureDelayGroups | 0.03148640601049
#  TaxiOut              | -0.025081334737153814
#  WheelsOff            | 0.001066452625305583
#  WheelsOn             | -0.018675949169265824
#  TaxiIn               | 0.009172502877008583
#  CRSArrTime           | -0.013126642184605398
#  ArrDelay             | 0.031247732673483387
#  ArrDel15             | 0.02986971057789118
#  ArrivalDelayGroups   | 0.039464351612297076
#  DistanceGroup        | -0.0054260583056338916
#  DivAirportLandings   | NaN
# -RECORD 14-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.00524733090314301
#  DepTime              | 0.004622519713885499
#  DepDelayMinutes      | 0.024381425973401365
#  DepDelay             | 0.028188729928695637
#  ArrTime              | -0.022688469246338328
#  ArrDelayMinutes      | 0.023061837300170435
#  AirTime              | -0.01675890855051634
#  CRSElapsedTime       | -0.027207337756154172
#  ActualElapsedTime    | -0.019510912405166017
#  Distance             | -0.005633650975211513
#  Year                 | NaN
#  Quarter              | 0.9175613064300949
#  Month                | 1.0
#  DayofMonth           | 0.006509392071567238
#  DayOfWeek            | 0.0196712963636972
#  OriginStateFips      | 0.0032609927860242425
#  OriginWac            | 0.008463944422058651
#  DestStateFips        | 0.0072724389175375295
#  DestWac              | 0.008827831965121782
#  DepDel15             | 0.038624583397303625
#  DepartureDelayGroups | 0.036672819909651946
#  TaxiOut              | -0.0307281447614716
#  WheelsOff            | 0.0014951426450032649
#  WheelsOn             | -0.021872353367430424
#  TaxiIn               | 0.009203808117919987
#  CRSArrTime           | -0.014750066313076573
#  ArrDelay             | 0.03720503654302924
#  ArrDel15             | 0.03468458266606202
#  ArrivalDelayGroups   | 0.04605778014709938
#  DistanceGroup        | -0.0060895273033648575
#  DivAirportLandings   | NaN
# -RECORD 15-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -9.979210338216616E-5
#  DepTime              | -0.0018170502850000405
#  DepDelayMinutes      | -0.012049551993937455
#  DepDelay             | -0.012384583289091252
#  ArrTime              | -0.0017396513047987056
#  ArrDelayMinutes      | -0.012668800299420935
#  AirTime              | -0.004775242124156686
#  CRSElapsedTime       | -0.00497741426678489
#  ActualElapsedTime    | -0.006172987386611147
#  Distance             | -0.002979639250339895
#  Year                 | NaN
#  Quarter              | 0.009165747744492832
#  Month                | 0.006509392071567238
#  DayofMonth           | 1.0
#  DayOfWeek            | -0.007449555980776081
#  OriginStateFips      | -6.365170769776915E-4
#  OriginWac            | 0.00513452836993632
#  DestStateFips        | -0.001339020618736427
#  DestWac              | 0.003992562152860416
#  DepDel15             | -0.015075152489997247
#  DepartureDelayGroups | -0.016281769207929918
#  TaxiOut              | -0.004364302604898903
#  WheelsOff            | -0.0021391577751854202
#  WheelsOn             | -0.0016382945493812427
#  TaxiIn               | -0.010288812372676079
#  CRSArrTime           | -0.001669239271142192
#  ArrDelay             | -0.013471121353947598
#  ArrDel15             | -0.016714050227964704
#  ArrivalDelayGroups   | -0.016956815773938337
#  DistanceGroup        | -0.0029518874026621088
#  DivAirportLandings   | NaN
# -RECORD 16-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.004984452898119005
#  DepTime              | 0.007429539519528246
#  DepDelayMinutes      | 0.029151057333275485
#  DepDelay             | 0.03196144196615611
#  ArrTime              | 1.648431657137716E-4
#  ArrDelayMinutes      | 0.028403939408936374
#  AirTime              | 0.007925780391683597
#  CRSElapsedTime       | 0.007810678923697986
#  ActualElapsedTime    | 0.009559832464337446
#  Distance             | 0.009617717766529633
#  Year                 | NaN
#  Quarter              | 0.03381206314631074
#  Month                | 0.0196712963636972
#  DayofMonth           | -0.007449555980776081
#  DayOfWeek            | 1.0
#  OriginStateFips      | -0.002304004640456833
#  OriginWac            | 0.004229986452324424
#  DestStateFips        | -0.0045674949258085575
#  DestWac              | 0.005023394560868065
#  DepDel15             | 0.04504544668113776
#  DepartureDelayGroups | 0.0444104172185428
#  TaxiOut              | 0.004496463630267855
#  WheelsOff            | 0.006340591404481982
#  WheelsOn             | 8.559344158199596E-4
#  TaxiIn               | 0.01356128757926509
#  CRSArrTime           | 0.003559264021151224
#  ArrDelay             | 0.03303555472017946
#  ArrDel15             | 0.04154389347669532
#  ArrivalDelayGroups   | 0.04374513897632562
#  DistanceGroup        | 0.009830063054572711
#  DivAirportLandings   | NaN
# -RECORD 17-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.014060136649506113
#  DepTime              | -0.009515190006684104
#  DepDelayMinutes      | 0.002690913873687306
#  DepDelay             | 5.862078910940324E-5
#  ArrTime              | -0.0020779401832956295
#  ArrDelayMinutes      | 0.00636070456903408
#  AirTime              | -0.05598355288155938
#  CRSElapsedTime       | -0.04397311629504004
#  ActualElapsedTime    | -0.043449850658032134
#  Distance             | -0.07901956100008559
#  Year                 | NaN
#  Quarter              | 0.003561649391763457
#  Month                | 0.0032609927860242425
#  DayofMonth           | -6.365170769776915E-4
#  DayOfWeek            | -0.002304004640456833
#  OriginStateFips      | 1.0
#  OriginWac            | -0.06408973234413577
#  DestStateFips        | 0.039860415085952276
#  DestWac              | -0.07066772874820673
#  DepDel15             | -0.015593327690624928
#  DepartureDelayGroups | -0.00544873207982461
#  TaxiOut              | 0.06591788545028178
#  WheelsOff            | -0.00304856434164255
#  WheelsOn             | -0.0031121335792120446
#  TaxiIn               | 0.02585291355372478
#  CRSArrTime           | -0.002567876195137521
#  ArrDelay             | 8.349405676137523E-4
#  ArrDel15             | -0.006185917155254019
#  ArrivalDelayGroups   | -0.002268909626011271
#  DistanceGroup        | -0.08423056632410007
#  DivAirportLandings   | NaN
# -RECORD 18-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.0061586629001304525
#  DepTime              | -0.013343583097882765
#  DepDelayMinutes      | -0.029049398071184087
#  DepDelay             | -0.026139099533031805
#  ArrTime              | 0.008221707898049784
#  ArrDelayMinutes      | -0.03629811414103378
#  AirTime              | -0.023469458374165787
#  CRSElapsedTime       | -0.040968748726779435
#  ActualElapsedTime    | -0.04429699857336228
#  Distance             | 0.026457827529463872
#  Year                 | NaN
#  Quarter              | 0.007998291037122277
#  Month                | 0.008463944422058651
#  DayofMonth           | 0.00513452836993632
#  DayOfWeek            | 0.004229986452324424
#  OriginStateFips      | -0.06408973234413577
#  OriginWac            | 1.0
#  DestStateFips        | -0.07208989437392238
#  DestWac              | 0.4698028730581482
#  DepDel15             | -0.025799382429220155
#  DepartureDelayGroups | -0.0348039881753762
#  TaxiOut              | -0.12646221332061278
#  WheelsOff            | -0.023617835404590462
#  WheelsOn             | 0.010037596615402515
#  TaxiIn               | -0.05210482978577475
#  CRSArrTime           | 0.0020506965077966757
#  ArrDelay             | -0.02939494271378611
#  ArrDel15             | -0.041150472426673836
#  ArrivalDelayGroups   | -0.04066470666228949
#  DistanceGroup        | 0.029756150848293993
#  DivAirportLandings   | NaN
# -RECORD 19-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.00917158250950291
#  DepTime              | 0.00631947737159933
#  DepDelayMinutes      | 0.0034141566542855925
#  DepDelay             | 7.511778173493388E-4
#  ArrTime              | 0.013069789262640715
#  ArrDelayMinutes      | 0.005776974177521961
#  AirTime              | -0.08504069527197906
#  CRSElapsedTime       | -0.0799486050693545
#  ActualElapsedTime    | -0.07695998651583101
#  Distance             | -0.0802470319116144
#  Year                 | NaN
#  Quarter              | 0.006791348036619248
#  Month                | 0.0072724389175375295
#  DayofMonth           | -0.001339020618736427
#  DayOfWeek            | -0.0045674949258085575
#  OriginStateFips      | 0.039860415085952276
#  OriginWac            | -0.07208989437392238
#  DestStateFips        | 1.0
#  DestWac              | -0.0661253303289756
#  DepDel15             | -0.004974831015731066
#  DepartureDelayGroups | -0.0015358970581161732
#  TaxiOut              | 0.036417681800778375
#  WheelsOff            | 0.006738139650440374
#  WheelsOn             | 0.01387800213119646
#  TaxiIn               | 0.011357685836482976
#  CRSArrTime           | 0.015569444874970648
#  ArrDelay             | 0.00478051234404228
#  ArrDel15             | 0.0010647940917706137
#  ArrivalDelayGroups   | 0.004066958109346216
#  DistanceGroup        | -0.08496825371265432
#  DivAirportLandings   | NaN
# -RECORD 20-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.018385717292485823
#  DepTime              | 0.02190488436616467
#  DepDelayMinutes      | -0.027123778263731337
#  DepDelay             | -0.0244830144464333
#  ArrTime              | 0.02054784079383739
#  ArrDelayMinutes      | -0.03519469196769234
#  AirTime              | 0.05831527353517117
#  CRSElapsedTime       | 0.04946061118163528
#  ActualElapsedTime    | 0.04097078970379641
#  Distance             | 0.026658972369600024
#  Year                 | NaN
#  Quarter              | 0.008532132475068318
#  Month                | 0.008827831965121782
#  DayofMonth           | 0.003992562152860416
#  DayOfWeek            | 0.005023394560868065
#  OriginStateFips      | -0.07066772874820673
#  OriginWac            | 0.4698028730581482
#  DestStateFips        | -0.0661253303289756
#  DestWac              | 1.0
#  DepDel15             | -0.022437513702813112
#  DepartureDelayGroups | -0.03025771319137201
#  TaxiOut              | -0.07290700777961799
#  WheelsOff            | 0.02527314194551015
#  WheelsOn             | 0.021652127348704524
#  TaxiIn               | -0.06735963020499039
#  CRSArrTime           | 0.016435710714075374
#  ArrDelay             | -0.03469717515315931
#  ArrDel15             | -0.04004873180752525
#  ArrivalDelayGroups   | -0.04279751700355314
#  DistanceGroup        | 0.030213098236923936
#  DivAirportLandings   | NaN
# -RECORD 21-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.18518275728484054
#  DepTime              | 0.23013527010175533
#  DepDelayMinutes      | 0.5251556922679033
#  DepDelay             | 0.544223571721839
#  ArrTime              | 0.0845557499401606
#  ArrDelayMinutes      | 0.4824071200678222
#  AirTime              | 0.03198242240785038
#  CRSElapsedTime       | 0.03076696567318076
#  ActualElapsedTime    | 0.035691183789176836
#  Distance             | 0.034081518796314506
#  Year                 | NaN
#  Quarter              | 0.03299390449608576
#  Month                | 0.038624583397303625
#  DayofMonth           | -0.015075152489997247
#  DayOfWeek            | 0.04504544668113776
#  OriginStateFips      | -0.015593327690624928
#  OriginWac            | -0.025799382429220155
#  DestStateFips        | -0.004974831015731066
#  DestWac              | -0.022437513702813112
#  DepDel15             | 1.0
#  DepartureDelayGroups | 0.7514898528181312
#  TaxiOut              | 0.03990800050585988
#  WheelsOff            | 0.22057187668446745
#  WheelsOn             | 0.09730127678437857
#  TaxiIn               | -0.00757512501040678
#  CRSArrTime           | 0.13911150358046517
#  ArrDelay             | 0.5305618789708284
#  ArrDel15             | 0.7458628826894542
#  ArrivalDelayGroups   | 0.688559279822915
#  DistanceGroup        | 0.03518118258375771
#  DivAirportLandings   | NaN
# -RECORD 22-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.1472672240944412
#  DepTime              | 0.19861727153156805
#  DepDelayMinutes      | 0.8046288044527046
#  DepDelay             | 0.8184852451518922
#  ArrTime              | 0.04302725883749446
#  ArrDelayMinutes      | 0.7740185403751902
#  AirTime              | 0.032079788562542504
#  CRSElapsedTime       | 0.03306331590777644
#  ActualElapsedTime    | 0.0390077155959112
#  Distance             | 0.03236767921179807
#  Year                 | NaN
#  Quarter              | 0.03148640601049
#  Month                | 0.036672819909651946
#  DayofMonth           | -0.016281769207929918
#  DayOfWeek            | 0.0444104172185428
#  OriginStateFips      | -0.00544873207982461
#  OriginWac            | -0.0348039881753762
#  DestStateFips        | -0.0015358970581161732
#  DestWac              | -0.03025771319137201
#  DepDel15             | 0.7514898528181312
#  DepartureDelayGroups | 1.0
#  TaxiOut              | 0.05286899238509641
#  WheelsOff            | 0.184876656391554
#  WheelsOn             | 0.054344912420466414
#  TaxiIn               | 0.00886001062674074
#  CRSArrTime           | 0.11334890494259144
#  ArrDelay             | 0.7960766321364344
#  ArrDel15             | 0.683364886403443
#  ArrivalDelayGroups   | 0.9244008716672075
#  DistanceGroup        | 0.033472282408139334
#  DivAirportLandings   | NaN
# -RECORD 23-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -9.956782710744342E-4
#  DepTime              | 0.008108219136773984
#  DepDelayMinutes      | 0.04286500685342134
#  DepDelay             | 0.042875764206242825
#  ArrTime              | 0.02554407377590659
#  ArrDelayMinutes      | 0.14716457600847246
#  AirTime              | 0.04773170964004704
#  CRSElapsedTime       | 0.07329058131418784
#  ActualElapsedTime    | 0.17944144068624684
#  Distance             | 0.030187209375568104
#  Year                 | NaN
#  Quarter              | -0.025081334737153814
#  Month                | -0.0307281447614716
#  DayofMonth           | -0.004364302604898903
#  DayOfWeek            | 0.004496463630267855
#  OriginStateFips      | 0.06591788545028178
#  OriginWac            | -0.12646221332061278
#  DestStateFips        | 0.036417681800778375
#  DestWac              | -0.07290700777961799
#  DepDel15             | 0.03990800050585988
#  DepartureDelayGroups | 0.05286899238509641
#  TaxiOut              | 1.0
#  WheelsOff            | 0.033844756498906545
#  WheelsOn             | 0.027762469109458295
#  TaxiIn               | 0.015157574426375053
#  CRSArrTime           | 0.021281902446641014
#  ArrDelay             | 0.17873754565424055
#  ArrDel15             | 0.23481167984857904
#  ArrivalDelayGroups   | 0.2423018362303087
#  DistanceGroup        | 0.028821095562472393
#  DivAirportLandings   | NaN
# -RECORD 24-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.9151107135981389
#  DepTime              | 0.9668895776479303
#  DepDelayMinutes      | 0.10646033393682264
#  DepDelay             | 0.11404069369085368
#  ArrTime              | 0.6268205905312795
#  ArrDelayMinutes      | 0.10017256177453779
#  AirTime              | -0.02743499343212044
#  CRSElapsedTime       | -0.0313325992334599
#  ActualElapsedTime    | -0.023878040618922815
#  Distance             | -0.027199728589956867
#  Year                 | NaN
#  Quarter              | 0.001066452625305583
#  Month                | 0.0014951426450032649
#  DayofMonth           | -0.0021391577751854202
#  DayOfWeek            | 0.006340591404481982
#  OriginStateFips      | -0.00304856434164255
#  OriginWac            | -0.023617835404590462
#  DestStateFips        | 0.006738139650440374
#  DestWac              | 0.02527314194551015
#  DepDel15             | 0.22057187668446745
#  DepartureDelayGroups | 0.184876656391554
#  TaxiOut              | 0.033844756498906545
#  WheelsOff            | 1.0
#  WheelsOn             | 0.66358511495721
#  TaxiIn               | -0.017547248790410502
#  CRSArrTime           | 0.7019569247070188
#  ArrDelay             | 0.11960162749871844
#  ArrDel15             | 0.197648731491794
#  ArrivalDelayGroups   | 0.17977682997647604
#  DistanceGroup        | -0.028430579351731752
#  DivAirportLandings   | NaN
# -RECORD 25-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.6079684001209741
#  DepTime              | 0.6400283014894176
#  DepDelayMinutes      | 0.019842656598162502
#  DepDelay             | 0.02521768174878014
#  ArrTime              | 0.9581516472798329
#  ArrDelayMinutes      | 0.021065876118400585
#  AirTime              | 0.016479540365156864
#  CRSElapsedTime       | 0.012748249491625748
#  ActualElapsedTime    | 0.02075879503138207
#  Distance             | 0.01192492353764605
#  Year                 | NaN
#  Quarter              | -0.018675949169265824
#  Month                | -0.021872353367430424
#  DayofMonth           | -0.0016382945493812427
#  DayOfWeek            | 8.559344158199596E-4
#  OriginStateFips      | -0.0031121335792120446
#  OriginWac            | 0.010037596615402515
#  DestStateFips        | 0.01387800213119646
#  DestWac              | 0.021652127348704524
#  DepDel15             | 0.09730127678437857
#  DepartureDelayGroups | 0.054344912420466414
#  TaxiOut              | 0.027762469109458295
#  WheelsOff            | 0.66358511495721
#  WheelsOn             | 1.0
#  TaxiIn               | 0.01149834407837531
#  CRSArrTime           | 0.8344925026831043
#  ArrDelay             | 0.03465295100808987
#  ArrDel15             | 0.08799016353882595
#  ArrivalDelayGroups   | 0.060487681636194196
#  DistanceGroup        | 0.015143326599531373
#  DivAirportLandings   | NaN
# -RECORD 26-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | -0.020649406906719393
#  DepTime              | -0.01806358546682881
#  DepDelayMinutes      | 0.014933658582335857
#  DepDelay             | 0.011015594386533831
#  ArrTime              | 0.011377052191596971
#  ArrDelayMinutes      | 0.08705146687941728
#  AirTime              | 0.07568193879107349
#  CRSElapsedTime       | 0.0937357667284863
#  ActualElapsedTime    | 0.16794742149410224
#  Distance             | 0.06877634433801308
#  Year                 | NaN
#  Quarter              | 0.009172502877008583
#  Month                | 0.009203808117919987
#  DayofMonth           | -0.010288812372676079
#  DayOfWeek            | 0.01356128757926509
#  OriginStateFips      | 0.02585291355372478
#  OriginWac            | -0.05210482978577475
#  DestStateFips        | 0.011357685836482976
#  DestWac              | -0.06735963020499039
#  DepDel15             | -0.00757512501040678
#  DepartureDelayGroups | 0.00886001062674074
#  TaxiOut              | 0.015157574426375053
#  WheelsOff            | -0.017547248790410502
#  WheelsOn             | 0.01149834407837531
#  TaxiIn               | 1.0
#  CRSArrTime           | 0.006684851581236487
#  ArrDelay             | 0.10661693652671067
#  ArrDel15             | 0.1392047310876398
#  ArrivalDelayGroups   | 0.1421275881868663
#  DistanceGroup        | 0.06750758612332793
#  DivAirportLandings   | NaN
# -RECORD 27-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.6858336434166958
#  DepTime              | 0.691165431303141
#  DepDelayMinutes      | 0.07015220254070503
#  DepDelay             | 0.07528798873696223
#  ArrTime              | 0.8206870695163324
#  ArrDelayMinutes      | 0.06715136809533924
#  AirTime              | 0.024924868775779888
#  CRSElapsedTime       | 0.022708945073579102
#  ActualElapsedTime    | 0.02768476180067025
#  Distance             | 0.02160125094268319
#  Year                 | NaN
#  Quarter              | -0.013126642184605398
#  Month                | -0.014750066313076573
#  DayofMonth           | -0.001669239271142192
#  DayOfWeek            | 0.003559264021151224
#  OriginStateFips      | -0.002567876195137521
#  OriginWac            | 0.0020506965077966757
#  DestStateFips        | 0.015569444874970648
#  DestWac              | 0.016435710714075374
#  DepDel15             | 0.13911150358046517
#  DepartureDelayGroups | 0.11334890494259144
#  TaxiOut              | 0.021281902446641014
#  WheelsOff            | 0.7019569247070188
#  WheelsOn             | 0.8344925026831043
#  TaxiIn               | 0.006684851581236487
#  CRSArrTime           | 1.0
#  ArrDelay             | 0.07893263383349626
#  ArrDel15             | 0.12891946276959484
#  ArrivalDelayGroups   | 0.11126938916947426
#  DistanceGroup        | 0.02532790367710093
#  DivAirportLandings   | NaN
# -RECORD 28-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.09929260516875582
#  DepTime              | 0.12495610950226806
#  DepDelayMinutes      | 0.9669400574964583
#  DepDelay             | 0.9687443897554385
#  ArrTime              | 0.026805820200931838
#  ArrDelayMinutes      | 0.986427638822554
#  AirTime              | 0.014607232851648546
#  CRSElapsedTime       | -0.003920446039479076
#  ActualElapsedTime    | 0.04757567716608211
#  Distance             | 0.0017111142667811839
#  Year                 | NaN
#  Quarter              | 0.031247732673483387
#  Month                | 0.03720503654302924
#  DayofMonth           | -0.013471121353947598
#  DayOfWeek            | 0.03303555472017946
#  OriginStateFips      | 8.349405676137523E-4
#  OriginWac            | -0.02939494271378611
#  DestStateFips        | 0.00478051234404228
#  DestWac              | -0.03469717515315931
#  DepDel15             | 0.5305618789708284
#  DepartureDelayGroups | 0.7960766321364344
#  TaxiOut              | 0.17873754565424055
#  WheelsOff            | 0.11960162749871844
#  WheelsOn             | 0.03465295100808987
#  TaxiIn               | 0.10661693652671067
#  CRSArrTime           | 0.07893263383349626
#  ArrDelay             | 1.0
#  ArrDel15             | 0.5731257592388513
#  ArrivalDelayGroups   | 0.834138125958373
#  DistanceGroup        | 0.00257691695929636
#  DivAirportLandings   | NaN
# -RECORD 29-------------------------------------
#  Cancelled            | NaN
#  Diverted             | NaN
#  CRSDepTime           | 0.1599517809077912
#  DepTime              | 0.20126609641306747
#  DepDelayMinutes      | 0.49173128111726633
#  DepDelay             | 0.507379721864141
#  ArrTime              | 0.0763319394300748
#  ArrDelayMinutes      | 0.5257058262060397
#  AirTime              | 0.04452799887998005
#  CRSElapsedTime       | 0.021982644986221156
#  ActualElapsedTime    | 0.08709242494615298
#  Distance             | 0.026769883173506773
#  Year                 | NaN
#  Quarter              | 0.02986971057789118
#  Month                | 0.03468458266606202
#  DayofMonth           | -0.016714050227964704
#  DayOfWeek            | 0.04154389347669532
#  OriginStateFips      | -0.006185917155254019
#  OriginWac            | -0.041150472426673836
#  DestStateFips        | 0.0010647940917706137
#  DestWac              | -0.04004873180752525
#  DepDel15             | 0.7458628826894542
#  DepartureDelayGroups | 0.683364886403443
#  TaxiOut              | 0.23481167984857904
#  WheelsOff            | 0.197648731491794
#  WheelsOn             | 0.08799016353882595
#  TaxiIn               | 0.1392047310876398
#  CRSArrTime           | 0.12891946276959484
#  ArrDelay             | 0.5731257592388513
#  ArrDel15             | 1.0
#  ArrivalDelayGroups   | 0.7603344995359986
#  DistanceGroup        | 0.02800757384899203
#  DivAirportLandings   | NaN
# only showing top 30 rows

# %% [markdown]
# ## Data Preprocessing

# %%
# Adicionando coluna Severity4 e definindo valores
df_filtered = df_filtered.withColumn('Severity4', col('Severity').cast('int'))
df_filtered = df_filtered.withColumn('Severity4', (col('Severity4') == 4).cast('int'))
df_filtered = df_filtered.drop('Severity')
df_filtered.groupBy('Severity4').count().show()
# Out:
# [Stage 9:======================================================>  (21 + 1) / 22]
# +---------+-------+
# |Severity4|  count|
# +---------+-------+
# |        1|  94421|
# |        0|3264408|
# +---------+-------+

# %%
# Criando um vetor de features para o modelo
target = 'Severity4'
feature_columns = df_filtered.columns
feature_columns.remove(target)

vector_assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
df_vector = vector_assembler.transform(df_filtered)

# %%
# Dividindo o conjunto de dados em treino e teste
train_data, test_data = df_vector.randomSplit([0.8, 0.2], seed=42)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Random Forest

# %%
# Criando e treinando um modelo de classificação (Random Forest)
rf_classifier = RandomForestClassifier(labelCol=target, featuresCol="features", numTrees=10)
pipeline = Pipeline(stages=[rf_classifier])
model = pipeline.fit(train_data)
# Out:
# [Stage 21:========================================>               (16 + 4) / 22]
# 24/02/16 00:07:12 WARN MemoryStore: Not enough space to cache rdd_64_16 in memory! (computed 19.7 MiB so far)
# 24/02/16 00:07:12 WARN BlockManager: Persisting block rdd_64_16 to disk instead.
# 24/02/16 00:07:12 WARN MemoryStore: Not enough space to cache rdd_64_17 in memory! (computed 29.6 MiB so far)
# 24/02/16 00:07:12 WARN BlockManager: Persisting block rdd_64_17 to disk instead.
# [Stage 21:=============================================>          (18 + 4) / 22]
# 24/02/16 00:07:15 WARN MemoryStore: Not enough space to cache rdd_64_19 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:15 WARN BlockManager: Persisting block rdd_64_19 to disk instead.
# [Stage 21:==================================================>     (20 + 2) / 22]
# 24/02/16 00:07:18 WARN MemoryStore: Not enough space to cache rdd_64_21 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:18 WARN BlockManager: Persisting block rdd_64_21 to disk instead.
# [Stage 21:=====================================================>  (21 + 1) / 22]
# 24/02/16 00:07:22 WARN MemoryStore: Not enough space to cache rdd_64_20 in memory! (computed 29.6 MiB so far)
# 24/02/16 00:07:22 WARN BlockManager: Persisting block rdd_64_20 to disk instead.
# 24/02/16 00:07:24 WARN MemoryStore: Not enough space to cache rdd_64_12 in memory! (computed 19.7 MiB so far)
# 24/02/16 00:07:24 WARN MemoryStore: Not enough space to cache rdd_64_11 in memory! (computed 19.7 MiB so far)
# 24/02/16 00:07:24 WARN MemoryStore: Not enough space to cache rdd_64_13 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:24 WARN MemoryStore: Not enough space to cache rdd_64_10 in memory! (computed 29.6 MiB so far)
# 24/02/16 00:07:25 WARN MemoryStore: Not enough space to cache rdd_64_12 in memory! (computed 3.7 MiB so far)
# 24/02/16 00:07:25 WARN MemoryStore: Not enough space to cache rdd_64_10 in memory! (computed 8.3 MiB so far)
# 24/02/16 00:07:25 WARN MemoryStore: Not enough space to cache rdd_64_13 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:25 WARN MemoryStore: Not enough space to cache rdd_64_11 in memory! (computed 19.7 MiB so far)
# 24/02/16 00:07:27 WARN MemoryStore: Not enough space to cache rdd_64_10 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:27 WARN MemoryStore: Not enough space to cache rdd_64_13 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:27 WARN MemoryStore: Not enough space to cache rdd_64_12 in memory! (computed 8.3 MiB so far)
# 24/02/16 00:07:27 WARN MemoryStore: Not enough space to cache rdd_64_11 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:29 WARN MemoryStore: Not enough space to cache rdd_64_12 in memory! (computed 8.3 MiB so far)
# 24/02/16 00:07:29 WARN MemoryStore: Not enough space to cache rdd_64_13 in memory! (computed 3.7 MiB so far)
# 24/02/16 00:07:29 WARN MemoryStore: Not enough space to cache rdd_64_10 in memory! (computed 13.1 MiB so far)
# 24/02/16 00:07:29 WARN MemoryStore: Not enough space to cache rdd_64_11 in memory! (computed 19.7 MiB so far)

# %%
# Fazendo previsões no conjunto de teste
predictions = model.transform(test_data)

# %%
# Avaliando o desempenho do modelo
evaluator = MulticlassClassificationEvaluator(labelCol="Severity4", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Accuracy:", accuracy)
# Out:
# [Stage 31:=====================================================>  (21 + 1) / 22]
# Accuracy: 0.972008995725541

# %%
# Salvando o DataFrame em formato Parquet
parquet_output_path="hdfs://spark-master:9000/datasets/accidents_output"
df_filtered.write.parquet(parquet_output_path)
